# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Train.csv")

# %%
# Group by road conditions and count the frequency of each
road_condition_counts = df['RDSFCOND'].value_counts().reset_index()
road_condition_counts.columns = ['Road Condition', 'Frequency']

# Create a bar plot using Plotly
fig = px.bar(road_condition_counts, x='Road Condition', y='Frequency',
             title='Frequency of Road Conditions in Traffic Collisions',
             labels={'Frequency': 'Collision Count', 'Road Condition': 'Road Condition'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="83337219-368a-4dec-97b1-21ef855ad9a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83337219-368a-4dec-97b1-21ef855ad9a9")) {                    Plotly.newPlot(                        "83337219-368a-4dec-97b1-21ef855ad9a9",                        [{"alignmentgroup":"True","hovertemplate":"Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Dry","Wet","Loose Snow","Other","Slush","Ice","Packed Snow","Loose Sand or Gravel","Spilled liquid"],"xaxis":"x","y":[11950,2549,144,135,94,63,40,5,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"col ...

# %%
# Group by state and road conditions, and count the frequency of each
state_road_condition_counts = df.groupby(['DISTRICT', 'RDSFCOND']).size().reset_index(name='Frequency')

# Create a bar plot using Plotly
fig = px.bar(state_road_condition_counts, x='DISTRICT', y='Frequency', color='RDSFCOND',
             title='Frequency of Road Conditions by State',
             labels={'Frequency': 'Collision Count', 'DISTRICT': 'State', 'RDSFCOND': 'Road Condition'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="212dbf9e-e068-4e52-8409-54ce7737ee07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("212dbf9e-e068-4e52-8409-54ce7737ee07")) {                    Plotly.newPlot(                        "212dbf9e-e068-4e52-8409-54ce7737ee07",                        [{"alignmentgroup":"True","hovertemplate":"Road Condition=Dry<br>State=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Dry","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Dry","offsetgroup":"Dry","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[2813,2379,2575,4175],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Ice<br>State=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Ice","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Ice","offsetgroup":"Ice","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[14,11,16,22],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Loose Sand or Gravel<br>State=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Loose Sand or Gravel","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Loose Sand or Gravel","offsetgroup":"Loose Sand or Gravel","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","Scarborough"],"xaxis":"x","y":[3,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Loose Snow<br>State=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Loose Snow","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Loose Snow","offsetgroup":"Loose Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[34,25,21,64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Other<br>State=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Other","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[42,19,24,50],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Packed Snow<br>State=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Packed Snow","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Packed Snow","offsetgroup":"Packed Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[10,8,7,15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Slush<br>State=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Slush","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Slush","offsetgroup":"Slush","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[22,23,17,32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Wet<br>State=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Wet","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Wet","offsetgroup":"Wet","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[542,516,626,859],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Spilled liquid<br>State=%{x}<br>Collisi ...

# %%
condition_counts = df.groupby(['RDSFCOND', 'VISIBILITY']).size().reset_index(name='Frequency')

# Create a bar plot using Plotly
fig = px.bar(condition_counts, x='RDSFCOND', y='Frequency', color='VISIBILITY',
             title='Frequency of Collisions by Road Conditions and Visibility',
             labels={'Frequency': 'Collision Count', 'RDSFCOND': 'Road Condition', 'VISIBILITY': 'Visibility'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="f463daca-f887-4640-98df-e603149708fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f463daca-f887-4640-98df-e603149708fb")) {                    Plotly.newPlot(                        "f463daca-f887-4640-98df-e603149708fb",                        [{"alignmentgroup":"True","hovertemplate":"Visibility=Clear<br>Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Ice","Loose Sand or Gravel","Loose Snow","Other","Packed Snow","Slush","Spilled liquid","Wet"],"xaxis":"x","y":[11915,16,5,31,58,3,33,1,802],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Drifting Snow<br>Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Drifting Snow","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Drifting Snow","offsetgroup":"Drifting Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Ice","Wet"],"xaxis":"x","y":[2,5,10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Fog, Mist, Smoke, Dust<br>Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Fog, Mist, Smoke, Dust","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fog, Mist, Smoke, Dust","offsetgroup":"Fog, Mist, Smoke, Dust","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Wet"],"xaxis":"x","y":[17,27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Other<br>Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Other","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Other","Wet"],"xaxis":"x","y":[12,73,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Rain<br>Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Rain","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Rain","offsetgroup":"Rain","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Packed Snow","Slush","Wet"],"xaxis":"x","y":[2,3,8,1600],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Snow<br>Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Snow","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Snow","offsetgroup":"Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Ice","Loose Snow","Other","Packed Snow","Slush","Wet"],"xaxis":"x","y":[2,24,113,4,34,37,89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Freezing Rain<br>Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Freezing Rain","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Freezing Rain","offsetgroup":"Freezing Rain","orientation":"v","showlegend":true,"textposition":"auto","x":["Ice","Slush","Wet"],"xaxis":"x","y":[15,14,12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Strong wind<br>Road Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Strong wind","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Strong wind","offsetgroup":"Strong wind","orientation":"v","showlegend":true,"textposition":"auto","x":["Ice","Slush","Wet"],"xaxis":"x","y":[3,2,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222 ...

# %%
yearly_collision_counts = df['YEAR'].value_counts().reset_index()
yearly_collision_counts.columns = ['Year', 'Collision Count']

# Sort the DataFrame by year
yearly_collision_counts = yearly_collision_counts.sort_values(by='Year')

# Create a line plot using Plotly
fig = px.bar(yearly_collision_counts, x='Year', y='Collision Count',
              title='Year-wise Occurrence of Collisions',
              labels={'Collision Count': 'Collision Count', 'Year': 'Year'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="a2557639-af27-4b1c-8b0b-d160b67bf856" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2557639-af27-4b1c-8b0b-d160b67bf856")) {                    Plotly.newPlot(                        "a2557639-af27-4b1c-8b0b-d160b67bf856",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[1483,1474,1239,1242,1190,1179,1348,1232,916,929,1006,980,782],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinew ...

# %%
# Group by year and state and count the occurrences of collisions
state_yearly_collision_counts = df.groupby(['DISTRICT', 'YEAR']).size().reset_index(name='Collision Count')

# Sort the DataFrame by year
state_yearly_collision_counts = state_yearly_collision_counts.sort_values(by=['DISTRICT', 'YEAR'])

# Create a grouped bar plot using Plotly
fig = px.bar(state_yearly_collision_counts, x='YEAR', y='Collision Count', color='DISTRICT',
             title='Year-wise Occurrence of Collisions by State',
             labels={'Collision Count': 'Collision Count', 'YEAR': 'Year', 'DISTRICT': 'State'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="19656bbb-9de9-4121-add9-faab1faf6023" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19656bbb-9de9-4121-add9-faab1faf6023")) {                    Plotly.newPlot(                        "19656bbb-9de9-4121-add9-faab1faf6023",                        [{"alignmentgroup":"True","hovertemplate":"State=Etobicoke York<br>Year=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Etobicoke York","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Etobicoke York","offsetgroup":"Etobicoke York","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[337,363,337,269,241,283,269,265,211,198,263,223,232],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=North York<br>Year=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"North York","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"North York","offsetgroup":"North York","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[287,273,255,242,195,241,232,206,206,213,203,222,209],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=Scarborough<br>Year=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Scarborough","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Scarborough","offsetgroup":"Scarborough","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[324,352,235,267,264,220,295,284,218,211,226,235,162],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=Toronto and East York<br>Year=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Toronto and East York","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Toronto and East York","offsetgroup":"Toronto and East York","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[535,486,412,464,490,435,552,477,279,300,314,295,179],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777 ...

# %%
# Group by light and visibility conditions and count the occurrences of collisions
light_visibility_counts = df.groupby(['LIGHT', 'VISIBILITY']).size().reset_index(name='Collision Count')

# Create a grouped bar plot using Plotly
fig = px.bar(light_visibility_counts, x='LIGHT', y='Collision Count', color='VISIBILITY',
             title='Comparison of Light and Visibility Conditions in Collisions',
             labels={'Collision Count': 'Collision Count', 'LIGHT': 'Light Condition', 'VISIBILITY': 'Visibility Condition'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="1e7d9ecb-c2c9-4389-9d61-f0904227149d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e7d9ecb-c2c9-4389-9d61-f0904227149d")) {                    Plotly.newPlot(                        "1e7d9ecb-c2c9-4389-9d61-f0904227149d",                        [{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear<br>Light Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Dawn","Dawn, artificial","Daylight","Daylight, artificial","Dusk","Dusk, artificial"],"xaxis":"x","y":[2655,1810,74,57,7888,89,165,131],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Drifting Snow<br>Light Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Drifting Snow","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Drifting Snow","offsetgroup":"Drifting Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight","Dusk, artificial"],"xaxis":"x","y":[2,5,8,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Fog, Mist, Smoke, Dust<br>Light Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Fog, Mist, Smoke, Dust","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fog, Mist, Smoke, Dust","offsetgroup":"Fog, Mist, Smoke, Dust","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight"],"xaxis":"x","y":[18,11,15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Freezing Rain<br>Light Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Freezing Rain","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Freezing Rain","offsetgroup":"Freezing Rain","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight"],"xaxis":"x","y":[21,9,11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Other<br>Light Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Other","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight","Dusk","Other"],"xaxis":"x","y":[37,4,47,1,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Rain<br>Light Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Rain","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Rain","offsetgroup":"Rain","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Dawn","Dawn, artificial","Daylight","Daylight, artificial","Dusk","Dusk, artificial"],"xaxis":"x","y":[555,371,24,21,576,10,35,21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Snow<br>Light Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Snow","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Snow","offsetgroup":"Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight","Dusk, artificial"],"xaxis":"x","y":[146,26,127,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Strong wind<br>Light Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Strong wind","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Strong wind","offsetgroup":"Strong wind","orientation":"v","showlegend":true,"textp ...

# %%
# Filter out rows with null age values and get unique age groups
valid_age_groups = df.dropna(subset=['INVAGE'])['INVAGE'].unique()

# Group by age group, light conditions, and visibility conditions, and count the occurrences of collisions
age_light_visibility_counts = df.groupby(['INVAGE', 'LIGHT', 'VISIBILITY']).size().reset_index(name='Collision Count')

# Filter only the rows with valid age groups
age_light_visibility_counts = age_light_visibility_counts[age_light_visibility_counts['INVAGE'].isin(valid_age_groups)]

# Create a grouped bar plot using Plotly
fig = px.bar(age_light_visibility_counts, x='INVAGE', y='Collision Count', color='VISIBILITY',
             facet_col='LIGHT', facet_col_wrap=3,
             title='Comparison of Light and Visibility Conditions by Age Group',
             labels={'Collision Count': 'Collision Count', 'INVAGE': 'Age Group', 'VISIBILITY': 'Visibility Condition'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="5c31920f-fc7b-4865-ae23-85bc66e7ef64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c31920f-fc7b-4865-ae23-85bc66e7ef64")) {                    Plotly.newPlot(                        "5c31920f-fc7b-4865-ae23-85bc66e7ef64",                        [{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear<br>LIGHT=Dark<br>Age Group=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":true,"textposition":"auto","x":["0 to 4","10 to 14","15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","5 to 9","50 to 54","55 to 59","60 to 64","65 to 69","70 to 74","75 to 79","80 to 84","85 to 89","90 to 94","Over 95","unknown"],"xaxis":"x7","y":[13,22,188,308,305,189,162,168,144,17,139,125,82,54,41,29,15,16,2,4,632],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear<br>LIGHT=Dark, artificial<br>Age Group=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["0 to 4","10 to 14","15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","5 to 9","50 to 54","55 to 59","60 to 64","65 to 69","70 to 74","75 to 79","80 to 84","85 to 89","90 to 94","Over 95","unknown"],"xaxis":"x8","y":[7,24,98,271,218,156,135,113,109,22,115,105,82,65,41,25,20,13,3,2,186],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear<br>LIGHT=Dawn<br>Age Group=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","50 to 54","55 to 59","60 to 64","65 to 69","70 to 74","unknown"],"xaxis":"x9","y":[4,5,4,8,4,9,6,3,8,3,3,1,16],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear<br>LIGHT=Dawn, artificial<br>Age Group=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["0 to 4","15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","50 to 54","55 to 59","60 to 64","65 to 69","75 to 79","80 to 84","85 to 89","unknown"],"xaxis":"x4","y":[1,1,6,4,6,3,3,7,7,5,4,2,2,1,1,4],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear<br>LIGHT=Daylight<br>Age Group=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["0 to 4","10 to 14","15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","5 to 9","50 to 54","55 to 59","60 to 64","65 to 69","70 to 74","75 to 79","80 to 84","85 to 89","90 to 94","Over 95","unknown"],"xaxis":"x5","y":[99,109,281,550,568,528,617,580,577,100,609,485,395,303,268,238,179,133,41,5,1223],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear<br>LIGHT=Daylight, artificial<br>Age Group=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["0 to 4","10 to 14","15 t ...

# %%
# Filter out rows with null age values and get unique age groups
valid_age_groups = df.dropna(subset=['INVAGE'])['INVAGE'].unique()

# Group by age group and count the occurrences of collisions
age_collision_counts = df['INVAGE'].value_counts().reset_index()
age_collision_counts.columns = ['Age Group', 'Collision Count']

# Filter only the rows with valid age groups
age_collision_counts = age_collision_counts[age_collision_counts['Age Group'].isin(valid_age_groups)]

# Create a bar plot using Plotly
fig = px.bar(age_collision_counts, x='Age Group', y='Collision Count',
             title='Collision Occurrences by Age Group',
             labels={'Collision Count': 'Collision Count', 'Age Group': 'Age Group'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="8a97ed81-1a31-4b98-b4de-56d658307400" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a97ed81-1a31-4b98-b4de-56d658307400")) {                    Plotly.newPlot(                        "8a97ed81-1a31-4b98-b4de-56d658307400",                        [{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["unknown","20 to 24","25 to 29","30 to 34","40 to 44","35 to 39","50 to 54","45 to 49","55 to 59","60 to 64","15 to 19","65 to 69","70 to 74","75 to 79","80 to 84","10 to 14","85 to 89","5 to 9","0 to 4","90 to 94","Over 95"],"xaxis":"x","y":[2493,1363,1304,1072,1067,1062,1060,1031,870,680,679,527,426,354,264,193,184,166,142,52,11],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f ...

# %%
# Group by injury type and count the occurrences of collisions
injury_collision_counts = df['INJURY'].value_counts().reset_index()
injury_collision_counts.columns = ['Injury Type', 'Collision Count']

# Create a bar plot using Plotly
fig = px.bar(injury_collision_counts, x='Injury Type', y='Collision Count',
             title='Collision Occurrences by Injury Type',
             labels={'Collision Count': 'Collision Count', 'Injury Type': 'Injury Type'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="b04f4a87-0e6a-4990-80b2-6452f9f11a59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b04f4a87-0e6a-4990-80b2-6452f9f11a59")) {                    Plotly.newPlot(                        "b04f4a87-0e6a-4990-80b2-6452f9f11a59",                        [{"alignmentgroup":"True","hovertemplate":"Injury Type=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Major","Minor","Minimal","Fatal"],"xaxis":"x","y":[4991,1183,936,701],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","mark ...

# %%
# Group by initial direction of travel and count the occurrences of collisions
initdir_collision_counts = df['INITDIR'].value_counts().reset_index()
initdir_collision_counts.columns = ['Initial Direction', 'Collision Count']

# Create a bar plot using Plotly
fig = px.bar(initdir_collision_counts, x='Initial Direction', y='Collision Count',
             title='Collision Occurrences by Initial Direction of Travel',
             labels={'Collision Count': 'Collision Count', 'Initial Direction': 'Initial Direction'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="c90a677f-8b9b-40f1-a258-b6d7c9913f27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c90a677f-8b9b-40f1-a258-b6d7c9913f27")) {                    Plotly.newPlot(                        "c90a677f-8b9b-40f1-a258-b6d7c9913f27",                        [{"alignmentgroup":"True","hovertemplate":"Initial Direction=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["East","West","South","North","Unknown"],"xaxis":"x","y":[2650,2552,2487,2452,361],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"s ...

# %%
# Group by driver condition and count the occurrences of collisions
drivcond_collision_counts = df['DRIVCOND'].value_counts().reset_index()
drivcond_collision_counts.columns = ['Driver Condition', 'Collision Count']

# Create a bar plot using Plotly
fig = px.bar(drivcond_collision_counts, x='Driver Condition', y='Collision Count',
             title='Collision Occurrences by Driver Condition',
             labels={'Collision Count': 'Collision Count', 'Driver Condition': 'Driver Condition'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="2bc4b0da-e94f-4554-8c9b-e203b0ab0b2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bc4b0da-e94f-4554-8c9b-e203b0ab0b2a")) {                    Plotly.newPlot(                        "2bc4b0da-e94f-4554-8c9b-e203b0ab0b2a",                        [{"alignmentgroup":"True","hovertemplate":"Driver Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Normal","Inattentive","Unknown","Medical or Physical Disability","Had Been Drinking","Ability Impaired, Alcohol Over .08","Ability Impaired, Alcohol","Fatigue","Other","Ability Impaired, Drugs"],"xaxis":"x","y":[4795,1226,814,144,138,107,100,47,38,12],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode ...

# %%
# Filter out rows with missing vehicle type
df_filtered = df.dropna(subset=['VEHTYPE'])

# Group by vehicle type and count the occurrences
collision_counts = df_filtered['VEHTYPE'].value_counts().reset_index()
collision_counts.columns = ['Vehicle Type', 'Collision Count']

# Create a bar chart using Plotly Express
fig = px.bar(collision_counts, x='Vehicle Type', y='Collision Count',
             title='Total Collision Comparison by Vehicle Type',
             labels={'Vehicle Type': 'Vehicle Type', 'Collision Count': 'Collision Count'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="52c2e38d-acf8-4d4a-938a-66d91b32a6ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52c2e38d-acf8-4d4a-938a-66d91b32a6ec")) {                    Plotly.newPlot(                        "52c2e38d-acf8-4d4a-938a-66d91b32a6ec",                        [{"alignmentgroup":"True","hovertemplate":"Vehicle Type=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Automobile, Station Wagon","Other","Bicycle","Motorcycle","Municipal Transit Bus (TTC)","Truck - Open","Pick Up Truck","Passenger Van","Delivery Van","Truck - Closed (Blazer, etc)","Street Car","Truck - Dump","Taxi","Truck-Tractor","Moped","Bus (Other) (Go Bus, Gray Coach)","Truck (other)","Intercity Bus","Tow Truck","Truck - Tank","School Bus","Police Vehicle","Construction Equipment","Fire Vehicle","Off Road - 2 Wheels","Other Emergency Vehicle","Truck - Car Carrier"],"xaxis":"x","y":[6154,4743,635,505,225,170,131,100,54,42,32,28,27,25,22,11,10,8,5,4,4,3,2,2,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}]," ...

# %%
# Filter out rows with missing pedestrian condition
df_filtered = df.dropna(subset=['PEDCOND'])

# Group by pedestrian condition and count the occurrences
collision_counts = df_filtered['PEDCOND'].value_counts().reset_index()
collision_counts.columns = ['Pedestrian Condition', 'Collision Count']

# Create a bar chart using Plotly Express
fig = px.bar(collision_counts, x='Pedestrian Condition', y='Collision Count',
             title='Total Collision Comparison by Pedestrian Condition',
             labels={'Pedestrian Condition': 'Pedestrian Condition', 'Collision Count': 'Collision Count'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="bb1a7306-206e-421f-981a-c2634799b05f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb1a7306-206e-421f-981a-c2634799b05f")) {                    Plotly.newPlot(                        "bb1a7306-206e-421f-981a-c2634799b05f",                        [{"alignmentgroup":"True","hovertemplate":"Pedestrian Condition=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Normal","Inattentive","Unknown","Had Been Drinking","Medical or Physical Disability","Other","Ability Impaired, Alcohol","Ability Impaired, Alcohol Over .80","Ability Impaired, Drugs","Fatigue"],"xaxis":"x","y":[1340,428,331,190,61,41,36,10,7,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode": ...

# %%
# Count the occurrences of each factor
counts = {
    'Cyclist Involved': df['CYCLIST'].notnull().sum(),
    'Pedestrian Involved': df['PEDESTRIAN'].notnull().sum(),
    'Transit or City Vehicle Involved': df['TRSN_CITY_VEH'].notnull().sum(),
    'Passenger Involved': df['PASSENGER'].notnull().sum(),
    'Speeding Related': df['SPEEDING'].notnull().sum(),
    'Red Light Related': df['REDLIGHT'].notnull().sum(),
    'Alcohol Related': df['ALCOHOL'].notnull().sum(),
}

# Create a DataFrame from the counts
data = pd.DataFrame.from_dict(counts, orient='index', columns=['Count']).reset_index()

# Rename columns
data.columns = ['Factor', 'Count']

# Create a bar chart using Plotly Express
fig = px.bar(data, x='Factor', y='Count',
             title='Total Accidents and Involvement of Different Factors',
             labels={'Factor': 'Factor', 'Count': 'Count'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="7382ff55-6767-4bb2-802a-286247e92c72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7382ff55-6767-4bb2-802a-286247e92c72")) {                    Plotly.newPlot(                        "7382ff55-6767-4bb2-802a-286247e92c72",                        [{"alignmentgroup":"True","hovertemplate":"Factor=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cyclist Involved","Pedestrian Involved","Transit or City Vehicle Involved","Passenger Involved","Speeding Related","Red Light Related","Alcohol Related"],"xaxis":"x","y":[1578,5966,923,5633,1998,1275,672],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo": ...

# %%
# Count the occurrences of each factor
counts = {
    'Cyclist Involved': df['CYCLIST'].notnull().sum(),
    'Pedestrian Involved': df['PEDESTRIAN'].notnull().sum(),
    'Transit or City Vehicle Involved': df['TRSN_CITY_VEH'].notnull().sum(),
    'Passenger Involved': df['PASSENGER'].notnull().sum(),
    'Speeding Related': df['SPEEDING'].notnull().sum(),
    'Red Light Related': df['REDLIGHT'].notnull().sum(),
    'Alcohol Related': df['ALCOHOL'].notnull().sum(),
}

# Create a DataFrame from the counts
data = pd.DataFrame.from_dict(counts, orient='index', columns=['Count']).reset_index()

# Rename columns
data.columns = ['Factor', 'Count']

# Create a pie chart using Plotly Express
fig = px.pie(data, names='Factor', values='Count',
             title='Distribution of Accidents by Factor')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="c882e9d7-8a25-4bf6-ba75-77fe0b0ba4cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c882e9d7-8a25-4bf6-ba75-77fe0b0ba4cd")) {                    Plotly.newPlot(                        "c882e9d7-8a25-4bf6-ba75-77fe0b0ba4cd",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Factor=%{label}<br>Count=%{value}<extra></extra>","labels":["Cyclist Involved","Pedestrian Involved","Transit or City Vehicle Involved","Passenger Involved","Speeding Related","Red Light Related","Alcohol Related"],"legendgroup":"","name":"","showlegend":true,"values":[1578,5966,923,5633,1998,1275,672],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":" ...

# %%
# Group by involvement type and count the occurrences
collision_counts = df_filtered['INVTYPE'].value_counts().reset_index()
collision_counts.columns = ['Involvement Type', 'Collision Count']

# Create a bar chart using Plotly Express
fig = px.bar(collision_counts, x='Involvement Type', y='Collision Count',
             title='Total Collisions by Involvement Type',
             labels={'Involvement Type': 'Involvement Type', 'Collision Count': 'Collision Count'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="276864b7-c0b9-4d52-8ed1-00d946b7cdad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("276864b7-c0b9-4d52-8ed1-00d946b7cdad")) {                    Plotly.newPlot(                        "276864b7-c0b9-4d52-8ed1-00d946b7cdad",                        [{"alignmentgroup":"True","hovertemplate":"Involvement Type=%{x}<br>Collision Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Pedestrian","Wheelchair","In-Line Skater"],"xaxis":"x","y":[2429,11,5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar" ...

# %%
# Define a function to map dates to seasons
def get_season(date):
    month = date.month
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Autumn'
    else:
        return 'Winter'

# Convert the 'DATE' column to datetime format if it's not already
df['DATE'] = pd.to_datetime(df['DATE'])

# Apply the function to create a new column for seasons
df['SEASON'] = df['DATE'].apply(get_season)

# Filter out rows with missing season information
df_filtered = df.dropna(subset=['SEASON'])

# Group by season and count the occurrences
season_counts = df_filtered['SEASON'].value_counts().reset_index()
season_counts.columns = ['Season', 'Accident Count']

# Create a bar chart using Plotly Express
fig = px.bar(season_counts, x='Season', y='Accident Count',
             title='Accidents by Season',
             labels={'Season': 'Season', 'Accident Count': 'Number of Accidents'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="1d85018f-e5d7-4007-b349-ffadc61d0e12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d85018f-e5d7-4007-b349-ffadc61d0e12")) {                    Plotly.newPlot(                        "1d85018f-e5d7-4007-b349-ffadc61d0e12",                        [{"alignmentgroup":"True","hovertemplate":"Season=%{x}<br>Number of Accidents=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Summer","Autumn","Spring","Winter"],"xaxis":"x","y":[4463,4013,3437,3087],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","m ...

# %%
# Filter out rows with missing season and district information
df_filtered = df.dropna(subset=['SEASON', 'DISTRICT'])

# Group by season and district and count the occurrences
season_district_counts = df_filtered.groupby(['DISTRICT', 'SEASON']).size().reset_index(name='Accident Count')

# Create a grouped bar chart using Plotly Express
fig = px.bar(season_district_counts, x='DISTRICT', y='Accident Count', color='SEASON',
             title='Accidents by District and Season',
             labels={'DISTRICT': 'District', 'Accident Count': 'Number of Accidents'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="23b74f5a-0f3e-4495-899d-8cd4adb9668f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23b74f5a-0f3e-4495-899d-8cd4adb9668f")) {                    Plotly.newPlot(                        "23b74f5a-0f3e-4495-899d-8cd4adb9668f",                        [{"alignmentgroup":"True","hovertemplate":"SEASON=Autumn<br>District=%{x}<br>Number of Accidents=%{y}<extra></extra>","legendgroup":"Autumn","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Autumn","offsetgroup":"Autumn","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[928,802,914,1361],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SEASON=Spring<br>District=%{x}<br>Number of Accidents=%{y}<extra></extra>","legendgroup":"Spring","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Spring","offsetgroup":"Spring","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[813,692,709,1223],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SEASON=Summer<br>District=%{x}<br>Number of Accidents=%{y}<extra></extra>","legendgroup":"Summer","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Summer","offsetgroup":"Summer","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[1018,892,932,1616],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SEASON=Winter<br>District=%{x}<br>Number of Accidents=%{y}<extra></extra>","legendgroup":"Winter","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Winter","offsetgroup":"Winter","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[732,598,738,1018],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"tic ...

# %%
# First result: Total null values for each feature
null_counts = df.isnull().sum()
null_df = pd.DataFrame(null_counts, columns=["Missing Values"])

# Second result: Total unique values for each feature
unique_values = df.nunique().reset_index()
unique_values.columns = ["Feature", "Unique Values"]

# Combine the two DataFrames
combined_df = pd.merge(unique_values, null_df, left_on="Feature", right_index=True)

# Display the combined DataFrame
print(combined_df)
# Out:
#               Feature  Unique Values  Missing Values
# 0              INDEX_          15000               0
# 1              ACCNUM           3822            3698
# 2                YEAR             13               0
# 3                DATE           3082               0
# 4                TIME           1276               0
# 5             STREET1           1547               0
# 6             STREET2           2344            1343
# 7              OFFSET            339           13072
# 8          ROAD_CLASS              9             357
# 9            DISTRICT              4              14
# 10            WARDNUM             71               0
# 11           LATITUDE           3475               0
# 12          LONGITUDE           3901               0
# 13           LOCCOORD              7              90
# 14             ACCLOC              9            5450
# 15           TRAFFCTL             10              29
# 16         VISIBILITY              8              14
# 17              LIGHT              9               0
# 18           RDSFCOND              9              19
# 19            ACCLASS              2               0
# 20          IMPACTYPE             10               0
# 21            INVTYPE             18              10
# 22             INVAGE             21               0
# 23             INJURY              4            7189
# 24           FATAL_NO             78           14407
# 25            INITDIR              5            4498
# 26            VEHTYPE             27            2055
# 27          MANOEUVER             16            6514
# 28            DRIVACT             13            7575
# 29           DRIVCOND             10            7579
# 30            PEDTYPE             16           12540
# 31             PEDACT             15           12550
# 32            PEDCOND             10           12555
# 33         CYCLISTYPE             22           14365
# 34             CYCACT             11           14379
# 35            CYCCOND             10           14380
# 36         PEDESTRIAN              1            9034
# 37            CYCLIST              1           13422
# 38         AUTOMOBILE              1            1328
# 39         MOTORCYCLE              1           13838
# 40              TRUCK              1           14067
# 41      TRSN_CITY_VEH              1           14077
# 42          EMERG_VEH              1           14981
# 43          PASSENGER              1            9367
# 44           SPEEDING              1           13002
# 45            AG_DRIV              1            7304
# 46           REDLIGHT              1           13725
# 47            ALCOHOL              1           14328
# 48         DISABILITY              1           14580
# 49           HOOD_158            159               0
# 50  NEIGHBOURHOOD_158            159               0
# 51           HOOD_140            141               0
# 52  NEIGHBOURHOOD_140            141               0
# 53           DIVISION             17               0
# 54           ObjectId          15000               0
# 55             SEASON              4               0

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# Accessing year, month, and day components
df['Year'] = df['DATE'].dt.year
df['Month'] = df['DATE'].dt.month
df['Day'] = df['DATE'].dt.day

# Displaying the updated DataFrame
print(df[['DATE', 'Year', 'Month', 'Day']].head())
# Out:
#                        DATE  Year  Month  Day
# 0 2006-01-07 05:00:00+00:00  2006      1    7
# 1 2006-01-07 05:00:00+00:00  2006      1    7
# 2 2006-01-07 05:00:00+00:00  2006      1    7
# 3 2006-01-09 05:00:00+00:00  2006      1    9
# 4 2006-01-09 05:00:00+00:00  2006      1    9

# %%
one_accident = df[df.duplicated(subset=[
    'YEAR',
    'DATE',
    'TIME',
    'STREET1',
    'WARDNUM',
    'LONGITUDE',
    'LATITUDE',
    'LIGHT',
    'HOOD_158',
    'NEIGHBOURHOOD_158',
    'HOOD_140',
    'NEIGHBOURHOOD_140',
    'DIVISION'
], keep=False)]

# Group by the condition and assign a unique index ID
one_accident['ACC_NUM'] = one_accident.groupby([
    'YEAR',
    'DATE',
    'TIME',
    'STREET1',
    'WARDNUM',
    'LONGITUDE',
    'LATITUDE',
    'LIGHT',
    'HOOD_158',
    'NEIGHBOURHOOD_158',
    'HOOD_140',
    'NEIGHBOURHOOD_140',
    'DIVISION'
]).ngroup()

# Merge the unique index IDs back to the original DataFrame
df = pd.merge(df, one_accident[['ACC_NUM']], left_index=True, right_index=True, how='left')
# Out:
# C:\Users\rajgo\AppData\Local\Temp\ipykernel_15996\3890231929.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['ACC_NUM'].count()
# Out:
# 14749

# %%
df['ACC_NUM'].isna().sum()
# Out:
# 251

# %%
df[df['ACC_NUM'].isna()].head(30)
# Out:
#         INDEX_       ACCNUM  YEAR                      DATE  TIME  \
# 96     3422670     905761.0  2006 2006-05-30 04:00:00+00:00  2328
# 120    3450204     916024.0  2006 2006-07-30 04:00:00+00:00  2155
# 161    3490523     930890.0  2006 2006-10-18 04:00:00+00:00  2136
# 983             Mid-Block                   NaN      No Control      Clear
# 1142            Mid-Block                   NaN      No Control       Rain
# 1267            Mid-Block                   NaN      No Control      Clear
# 1291         Intersection                   NaN      No Control       Snow
# 1308            Mid-Block                   NaN      No Control       Rain
# 1348            Mid-Block                   NaN      No Control      Clear
# 1353            Mid-Block                   NaN      No Control      Clear
# 1360            Mid-Block                   NaN      No Control       Rain
# 1434         Intersection      Non Intersection       Stop Sign      Clear
# 1458            Mid-Block                   NaN      No Control      Clear
# 1483            Mid-Block                   NaN      No Control       Rain
# 1486            Mid-Block      Non Intersection      No Control      Clear
# 1541            Mid-Block                   NaN      No Control      Clear
# 1584            Mid-Block      Non Intersection      No Control      Clear
# 1636         Intersection       At Intersection      No Control      Clear
# 1645            Mid-Block      Non Intersection      No Control      Clear
# 1689            Mid-Block                   NaN      No Control      Clear
# 1708         Intersection      Non Intersection      No Control      Clear
# 1809            Mid-Block    Overpass or Bridge      No Control       Rain
# 1815         Intersection  Intersection Related      No Control      Clear
# 1821            Mid-Block      Non Intersection      No Control      Clear
# 1829            Mid-Block      Non Intersection      No Control      Clear
#
#                  LIGHT     RDSFCOND ACCLASS              IMPACTYPE  \
# 96                Dark          Dry   Fatal              SMV Other
# 120               Dark          Dry   Fatal              SMV Other
# 161               Dark          Dry   Fatal              SMV Other
# 309               Dark          Dry   Fatal              SMV Other
# 310               Dark          Dry   Fatal              SMV Other
# 434               Dark          Dry   Fatal              SMV Other
# 504               Dark          Wet   Fatal              SMV Other
# 961               Dark  Packed Snow   Fatal              SMV Other
# 983           Daylight          Dry   Fatal              SMV Other
# 1142          Daylight          Wet   Fatal              SMV Other
# 1267  Dawn, artificial          Dry   Fatal              SMV Other
# 1291          Daylight        Slush   Fatal              SMV Other
# 1308          Daylight          Wet   Fatal              SMV Other
# 1348          Daylight          Wet   Fatal              SMV Other
# 1353          Daylight          Dry   Fatal              SMV Other
# 1360  Dark, artificial          Wet   Fatal              SMV Other
# 1434  Dark, artificial          Dry   Fatal              SMV Other
# 1458  Dark, artificial          Dry   Fatal              SMV Other
# 1483              Dark          Wet   Fatal              SMV Other
# 1486          Daylight          Dry   Fatal              SMV Other
# 1541  Dark, artificial          Dry   Fatal              SMV Other
# 1584          Daylight          Dry   Fatal  Pedestrian Collisions
# 1636          Daylight          Dry   Fatal              SMV Other
# 1645  Dark, artificial          Wet   Fatal              SMV Other
# 1689          Daylight          Dry   Fatal               Rear End
# 1708          Daylight          Dry   Fatal                  Other
# 1809          Daylight          Wet   Fatal              SMV Other
# 1815              Dark          Dry   Fatal              SMV Other
# 1821              Dark          Dry   Fatal              SMV Other
# 1829          Daylight          Dry   Fatal              SMV Other
#
#                 INVTYPE    INVAGE INJURY  FATAL_NO  INITDIR  \
# 96    Motorcycle Driver  25 to 29  Fatal       NaN     East
# 120   Motorcycle Driver  20 to 24  Fatal       NaN     West
# 161   Motorcycle Driver  20 to 24  Fatal       NaN     West
# 309   Motorcycle Driver  25 to 29  Fatal       NaN     West
# 310              Driver  40 to 44  Fatal       NaN     East
NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 1809        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 1815        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 1821        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 1829        NaN     NaN        Yes        NaN   NaN           NaN       NaN
#
#      PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158  \
# 96         NaN      NaN     Yes      NaN     NaN        NaN       71
# 120        NaN      NaN     NaN      NaN     NaN        NaN       85
# 161        NaN      NaN     NaN      NaN     NaN        NaN      144
# 309        NaN      NaN     NaN      NaN     NaN        NaN       85
# 310        NaN      NaN     NaN      NaN     NaN        NaN      155
# 434        NaN      Yes     Yes      NaN     NaN        NaN       98
# 504        NaN      Yes     Yes      NaN     NaN        NaN      154
# 961        NaN      NaN     NaN      NaN     NaN        NaN       47
# 983        NaN      Yes     Yes      NaN     NaN        NaN       68
# 1142       NaN      NaN     NaN      NaN     NaN        NaN       85
# 1267       NaN      Yes     Yes      NaN     NaN        NaN       85
# 1291       NaN      NaN     NaN      NaN     NaN        NaN       15
# 1308       NaN      NaN     NaN      NaN     NaN        NaN       68
# 1348       NaN      Yes     Yes      NaN     NaN        NaN        5
# 1353       NaN      Yes     Yes      NaN     NaN        NaN      135
# 1360       NaN      Yes     Yes      NaN     Yes        NaN       58
# 1434       NaN      NaN     NaN      NaN     NaN        NaN        7
# 1458       NaN      Yes     Yes      NaN     NaN        NaN       68
# 1483       NaN      Yes     Yes      NaN     NaN        NaN       16
# 1486       NaN      NaN     NaN      NaN     NaN        NaN       85
# 1541       NaN      Yes     Yes      NaN     NaN        NaN      163
# 1584       NaN      NaN     NaN      NaN     NaN        NaN      101
# 1636       NaN      NaN     NaN      NaN     NaN        Yes       18
# 1645       NaN      Yes     Yes      NaN     NaN        NaN       19
# 1689       NaN      Yes     Yes      NaN     NaN        NaN       21
# 1708       NaN      NaN     NaN      NaN     NaN        NaN      110
# 1809       NaN      Yes     Yes      NaN     NaN        NaN       70
# 1815       NaN      Yes     Yes      NaN     NaN        NaN      120
# 1821       NaN      Yes     Yes      NaN     NaN        NaN       85
# 1829       NaN      NaN     NaN      NaN     NaN        Yes      119
#
#                      NEIGHBOURHOOD_158 HOOD_140  \
# 96     Cabbagetown-South St.James Town       71
# 120                     South Parkdale       85
# 161                Morningside Heights      131
# 309                     South Parkdale       85
# 310                          Downsview       26
# 434                Rosedale-Moore Park       98
# 504           Oakdale-Beverley Heights       26
# 961                 Don Valley Village       47
# 983                    North Riverdale       68
# 1142                    South Parkdale       85
# 1267                    South Parkdale       85
# 1291                    Kingsway South       15
# 1308                   North Riverdale       68
# 1348                  Elms-Old Rexdale        5
# 1353                       Morningside      135
# 1360                     Old East York       58
# 1434  Willowridge-Martingrove-Richview        7
# 1458                   North Riverdale       68
# 1483               Stonegate-Queensway       16
# 1486                    South Parkdale       85
# 1541         Fort York-Liberty Village       82
# 1584                 Forest Hill South      101
# 1636                       New Toronto       18
# 1645                       Long Branch       19
# 1689                     Humber Summit       21
# 1708          Keelesdale-Eglinton West      110
# 1809                   South Riverdale       70
# 1815               Clairlea-Birchmount      120
# 1821                    South Parkdale       85
# 1829                  Wexford/Maryvale      119
#
#                          NEIGHBOURHOOD_140 DIVISION  ObjectId  SEASON  Year  \
# 96    Cabbagetown-South St.James Town (71)      D51       660  Spring  2006
# 120                    South Parkdale (85)      D11       881  Summer  2006
# 161                            Rouge (131)      D42      1142  Autumn  2006
# 309                    South Parkdale (85)      D14      2559  Summer  2007
# 310              Downsview-Roding-CFB (26)      D31      2917  Autumn  2007
# 434               Rosedale-Moore Park (98)      D53      3904  Spring  2008
# 504              Downsview-Roding-CFB (26)      D31      3991  Autumn  2008
# 961                Don Valley Village (47)      D33      7525  Winter  2012
# 983                   North Riverdale (68)      D55      8695  Spring  2012
# 1142                   South Parkdale (85)      D14      9471  Summer  2013
# 1267                   South Parkdale (85)      D11     10356  Autumn  2013
# 1291                   Kingsway South (15)      D22     10381  Spring  2014
# 1308                  North Riverdale (68)      D55     10920  Summer  2014
# 1348                  Elms-Old Rexdale (5)      D23     11563  Autumn  2014
# 1353                     Morningside (135)      D43     11573  Autumn  2014
# 1360                    Old East York (58)      D55     11919  Autumn  2014
# 1434  Willowridge-Martingrove-Richview (7)      D23     11098  Spring  2015
# 1458                  North Riverdale (68)      D55     11304  Winter  2015
# 1483              Stonegate-Queensway (16)      D22     11479  Summer  2015
# 1486                   South Parkdale (85)      D14     11502  Autumn  2015
# 1541                          Niagara (82)      D14     11945  Spring  2015
# 1584               Forest Hill South (101)      D13     12292  Autumn  2015
# 1636                      New Toronto (18)      D22     12531  Summer  2016
# 1645                      Long Branch (19)      D22     12579  Winter  2016
# 1689                    Humber Summit (21)      D31     12808  Spring  2016
# 1708        Keelesdale-Eglinton West (110)      D12     12914  Spring  2016
# 1809                  South Riverdale (70)      NSA     13615  Autumn  2016
# 1815             Clairlea-Birchmount (120)      D41     13656  Autumn  2016
# 1821                   South Parkdale (85)      D14     13668  Autumn  2016
# 1829                Wexford/Maryvale (119)      D41     13692  Spring  2017
#
#       Month  Day  ACC_NUM
# 96        5   30      NaN
# 120       7   30      NaN
# 161      10   18      NaN
# 309       8   30      NaN
# 310       9    2      NaN
# 434       5   24      NaN
# 504       9   28      NaN
# 961       1   20      NaN
# 983       4   20      NaN
# 1142      6   16      NaN
# 1267     11   29      NaN
# 1291      3    6      NaN
# 1308      6   16      NaN
# 1348     10    1      NaN
# 1353     11    4      NaN
# 1360     11   24      NaN
# 1434      5   27      NaN
# 1458      1   11      NaN
# 1483      6   13      NaN
# 1486      9    6      NaN
# 1541      4    1      NaN
# 1584     11   14      NaN
# 1636      7   12      NaN
# 1645      1    8      NaN
# 1689      3    9      NaN
# 1708      5   30      NaN
# 1809     10   27      NaN
# 1815     10   30      NaN
# 1821     10   31      NaN
# 1829      5   16      NaN

# %%
pd.set_option('display.max_columns', None)

# %%
df.drop("INDEX_", axis=1, inplace=True)

# %%
df[df['ACC_NUM'].isna()].head(30)
# Out:
#        ACCNUM  YEAR                      DATE  TIME                 STREET1  \
# 31   885650.0  2006 2006-01-29 05:00:00+00:00  2048    F G GARDINER XY W  W
# 32   885650.0  2006 2006-01-29 05:00:00+00:00  2048    F G GARDINER XY W  W
# 45   891993.0  2006 2006-03-06 05:00:00+00:00  2222      F G GARDINER XY  W
# 166            Mid-Block    NaN  No Control      Clear      Dark      Wet
# 167            Mid-Block    NaN  No Control      Clear      Dark      Wet
# 168            Mid-Block    NaN  No Control      Clear      Dark      Wet
# 169            Mid-Block    NaN  No Control      Clear      Dark      Wet
# 206            Mid-Block    NaN  No Control      Clear      Dark      Dry
# 207            Mid-Block    NaN  No Control      Clear      Dark      Dry
# 208            Mid-Block    NaN  No Control      Clear      Dark      Dry
# 209            Mid-Block    NaN  No Control      Clear      Dark      Dry
# 210            Mid-Block    NaN  No Control      Clear      Dark      Dry
#
#     ACCLASS              IMPACTYPE               INVTYPE    INVAGE   INJURY  \
# 31    Fatal  Pedestrian Collisions                Driver  20 to 24      NaN
# 32    Fatal  Pedestrian Collisions            Pedestrian  15 to 19    Fatal
# 45    Fatal              Sideswipe             Passenger  15 to 19    Fatal
# 46    Fatal              Sideswipe             Passenger  20 to 24    Minor
# 47    Fatal              Sideswipe                Driver  35 to 39    Minor
# 48    Fatal              Sideswipe         Vehicle Owner   unknown      NaN
# 49    Fatal              Sideswipe                Driver  25 to 29    Minor
# 50    Fatal              Sideswipe                Driver  40 to 44      NaN
# 51    Fatal              Sideswipe  Other Property Owner   unknown      NaN
# 52    Fatal               Rear End             Passenger    5 to 9    Fatal
# 53    Fatal               Rear End             Passenger    5 to 9    Major
# 54    Fatal               Rear End             Passenger  40 to 44    Minor
# 55    Fatal               Rear End                 Other   unknown      NaN
# 56    Fatal               Rear End                Driver  30 to 34    Minor
# 96    Fatal              SMV Other     Motorcycle Driver  25 to 29    Fatal
# 120   Fatal              SMV Other     Motorcycle Driver  20 to 24    Fatal
# 149   Fatal              SMV Other         Vehicle Owner   unknown      NaN
# 150   Fatal              SMV Other     Motorcycle Driver  30 to 34    Fatal
# 161   Fatal              SMV Other     Motorcycle Driver  20 to 24    Fatal
# 164   Fatal              Sideswipe                Driver  45 to 49    Fatal
# 165   Fatal              Sideswipe             Passenger  25 to 29      NaN
# 166   Fatal              Sideswipe                Driver  60 to 64    Minor
# 167   Fatal              Sideswipe             Passenger  50 to 54    Minor
# 168   Fatal              Sideswipe         Vehicle Owner   unknown      NaN
# 169   Fatal              Sideswipe                Driver  60 to 64    Minor
# 206   Fatal               Rear End         Vehicle Owner   unknown      NaN
# 207   Fatal               Rear End          Truck Driver  25 to 29  Minimal
# 208   Fatal               Rear End         Vehicle Owner   unknown      NaN
# 209   Fatal               Rear End          Truck Driver  50 to 54      NaN
# 210   Fatal               Rear End                Driver  30 to 34    Fatal
#
#      FATAL_NO INITDIR                    VEHTYPE       MANOEUVER  \
# 31        NaN    West  Automobile, Station Wagon     Going Ahead
# 32        NaN   South                      Other             NaN
# 45        NaN     NaN                      Other             NaN
# 46        NaN     NaN                      Other             NaN
# 47        NaN    West  Automobile, Station Wagon      Overtaking
# 48        NaN     NaN                      Other             NaN
# 49        NaN    West  Automobile, Station Wagon     Going Ahead
# 50        NaN    West  Automobile, Station Wagon     Going Ahead
# 51        NaN     NaN                      Other             NaN
# 52        NaN     NaN                      Other             NaN
# 53        NaN     NaN                      Other             NaN
# 54        NaN     NaN                      Other             NaN
# 55        NaN    East                      Other          Parked
# 56        NaN    East  Automobile, Station Wagon     Going Ahead
# 96        NaN    East                 Motorcycle     Going Ahead
# 120       NaN    West                 Motorcycle     Going Ahead
# 149       NaN     NaN                      Other           Other
# 150       NaN    West                 Motorcycle     Going Ahead
# 161       NaN    West                 Motorcycle     Going Ahead
# 164       NaN    West  Automobile, Station Wagon     Going Ahead
# 165       NaN     NaN                      Other             NaN
# 166       NaN    West  Automobile, Station Wagon     Going Ahead
# 167       NaN     NaN                      Other             NaN
# 168       NaN     NaN                      Other             NaN
# 169       NaN    West  Automobile, Station Wagon     Going Ahead
# 206       NaN     NaN                      Other     Going Ahead
# 207       NaN    West               Truck - Open     Going Ahead
# 208       NaN     NaN                      Other     Going Ahead
# 209       NaN    West               Truck - Open     Going Ahead
# 210       NaN    West  Automobile, Station Wagon  Changing Lanes
#
#                   DRIVACT                            DRIVCOND  \
# 31       Driving Properly                              Normal
# 32                    NaN                                 NaN
# 45                    NaN                                 NaN
# 46                    NaN                                 NaN
# 47           Lost control  Ability Impaired, Alcohol Over .08
# 48                    NaN                                 NaN
# 49       Driving Properly                              Normal
# 50       Driving Properly                              Normal
# 51                    NaN                                 NaN
# 52                    NaN                                 NaN
# 53                    NaN                                 NaN
# 54                    NaN                                 NaN
# 55                    NaN                                 NaN
# 56           Lost control                         Inattentive
# 96           Lost control                              Normal
# 120          Lost control                             Unknown
# 149                   NaN                                 NaN
# 150          Lost control                             Unknown
# 161          Lost control                         Inattentive
# 164          Lost control                             Unknown
# 165                   NaN                                 NaN
# 166      Driving Properly                              Normal
# 167                   NaN                                 NaN
# 168                   NaN                                 NaN
# 169      Driving Properly                              Normal
# 206                   NaN                                 NaN
# 207      Driving Properly                              Normal
# 208                   NaN                                 NaN
# 209      Driving Properly                              Normal
# 210  Improper Lane Change                             Unknown
#
#                          PEDTYPE                PEDACT  PEDCOND CYCLISTYPE  \
# 31                           NaN                   NaN      NaN        NaN
# 32   Pedestrian hit at mid-block  Running onto Roadway  Unknown        NaN
# 45                           NaN                   NaN      NaN        NaN
# 46                           NaN                   NaN      NaN        NaN
# 47                           NaN                   NaN      NaN        NaN
# 48                           NaN                   NaN      NaN        NaN
# 49                           NaN                   NaN      NaN        NaN
# 50                           NaN                   NaN      NaN        NaN
# 51                           NaN                   NaN      NaN        NaN
# 52                           NaN                   NaN      NaN        NaN
# 53                           NaN                   NaN      NaN        NaN
# 54                           NaN                   NaN      NaN        NaN
# 55                           NaN                   NaN      NaN        NaN
# 56                           NaN                   NaN      NaN        NaN
# 96                           NaN                   NaN      NaN        NaN
# 120                          NaN                   NaN      NaN        NaN
# 149                          NaN                   NaN      NaN        NaN
# 150                          NaN                   NaN      NaN        NaN
# 161                          NaN                   NaN      NaN        NaN
# 164                          NaN                   NaN      NaN        NaN
# 165                          NaN                   NaN      NaN        NaN
# 166                          NaN                   NaN      NaN        NaN
# 167                          NaN                   NaN      NaN        NaN
# 168                          NaN                   NaN      NaN        NaN
# 169                          NaN                   NaN      NaN        NaN
# 206                          NaN                   NaN      NaN        NaN
# 207                          NaN                   NaN      NaN        NaN
# 208                          NaN                   NaN      NaN        NaN
# 209                          NaN                   NaN      NaN        NaN
# 210                          NaN                   NaN      NaN        NaN
#
#     CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK  \
# 31     NaN     NaN        Yes     NaN        Yes        NaN   NaN
# 32     NaN     NaN        Yes     NaN        Yes        NaN   NaN
# 45     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 46     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 47     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 48     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 49     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 50     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 51     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 52     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 53     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 54     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 55     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 56     NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 96     NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 120    NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 149    NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 150    NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 161    NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 164    NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 165    NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 166    NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 167    NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 168    NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 169    NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 206    NaN     NaN        NaN     NaN        Yes        NaN   Yes
# 207    NaN     NaN        NaN     NaN        Yes        NaN   Yes
# 208    NaN     NaN        NaN     NaN        Yes        NaN   Yes
# 209    NaN     NaN        NaN     NaN        Yes        NaN   Yes
# 210    NaN     NaN        NaN     NaN        Yes        NaN   Yes
#
#     TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL  \
# 31            NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 32            NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 45            NaN       NaN       Yes      NaN     NaN      NaN     Yes
# 46            NaN       NaN       Yes      NaN     NaN      NaN     Yes
# 47            NaN       NaN       Yes      NaN     NaN      NaN     Yes
# 48            NaN       NaN       Yes      NaN     NaN      NaN     Yes
# 49            NaN       NaN       Yes      NaN     NaN      NaN     Yes
# 50            NaN       NaN       Yes      NaN     NaN      NaN     Yes
# 51            NaN       NaN       Yes      NaN     NaN      NaN     Yes
# 52            NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 53            NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 54            NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 55            NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 56            NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 96            NaN       NaN       NaN      NaN     Yes      NaN     NaN
# 120           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 149           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 150           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 161           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 164           NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 165           NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 166           NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 167           NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 168           NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 169           NaN       NaN       Yes      NaN     NaN      NaN     NaN
# 206           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 207           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 208           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 209           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 210           NaN       NaN       NaN      NaN     NaN      NaN     NaN
#
#     DISABILITY HOOD_158                NEIGHBOURHOOD_158 HOOD_140  \
# 31         NaN      160                 Mimico-Queensway       17
# 32         NaN      160                 Mimico-Queensway       17
# 45         NaN      161                Humber Bay Shores       17
# 46         NaN      161                Humber Bay Shores       17
# 47         NaN      161                Humber Bay Shores       17
# 48         NaN      161                Humber Bay Shores       17
# 49         NaN      161                Humber Bay Shores       17
# 50         NaN      161                Humber Bay Shores       17
# 51         NaN      161                Humber Bay Shores       17
# 52         NaN      160                 Mimico-Queensway       17
# 53         NaN      160                 Mimico-Queensway       17
# 54         NaN      160                 Mimico-Queensway       17
# 55         NaN      160                 Mimico-Queensway       17
# 56         NaN      160                 Mimico-Queensway       17
# 96         NaN       71  Cabbagetown-South St.James Town       71
# 120        NaN       85                   South Parkdale       85
# 149        NaN      163        Fort York-Liberty Village       82
# 150        NaN      163        Fort York-Liberty Village       82
# 161        NaN      144              Morningside Heights      131
# 164        NaN      161                Humber Bay Shores       17
# 165        NaN      161                Humber Bay Shores       17
# 166        NaN      161                Humber Bay Shores       17
# 167        NaN      161                Humber Bay Shores       17
# 168        NaN      161                Humber Bay Shores       17
# 169        NaN      161                Humber Bay Shores       17
# 206        NaN       85                   South Parkdale       85
# 207        NaN       85                   South Parkdale       85
# 208        NaN       85                   South Parkdale       85
# 209        NaN       85                   South Parkdale       85
# 210        NaN       85                   South Parkdale       85
#
#                             NEIGHBOURHOOD_140 DIVISION  ObjectId  SEASON  \
# 31   Mimico (includes Humber Bay Shores) (17)      D22       603  Winter
# 32   Mimico (includes Humber Bay Shores) (17)      D22       611  Winter
# 45   Mimico (includes Humber Bay Shores) (17)      D22       288  Spring
# 46   Mimico (includes Humber Bay Shores) (17)      D22       289  Spring
# 47   Mimico (includes Humber Bay Shores) (17)      D22       290  Spring
# 48   Mimico (includes Humber Bay Shores) (17)      D22       291  Spring
# 49   Mimico (includes Humber Bay Shores) (17)      D22       292  Spring
# 50   Mimico (includes Humber Bay Shores) (17)      D22       293  Spring
# 51   Mimico (includes Humber Bay Shores) (17)      D22       294  Spring
# 52   Mimico (includes Humber Bay Shores) (17)      D22       295  Spring
# 53   Mimico (includes Humber Bay Shores) (17)      D22       296  Spring
# 54   Mimico (includes Humber Bay Shores) (17)      D22       297  Spring
# 55   Mimico (includes Humber Bay Shores) (17)      D22       298  Spring
# 56   Mimico (includes Humber Bay Shores) (17)      D22       299  Spring
# 96       Cabbagetown-South St.James Town (71)      D51       660  Spring
# 120                       South Parkdale (85)      D11       881  Summer
# 149                              Niagara (82)      D14       807  Summer
# 150                              Niagara (82)      D14       810  Summer
# 161                               Rouge (131)      D42      1142  Autumn
# 164  Mimico (includes Humber Bay Shores) (17)      D22      1709  Autumn
# 165  Mimico (includes Humber Bay Shores) (17)      D22      1727  Autumn
# 166  Mimico (includes Humber Bay Shores) (17)      D22      1735  Autumn
# 167  Mimico (includes Humber Bay Shores) (17)      D22      1747  Autumn
# 168  Mimico (includes Humber Bay Shores) (17)      D22      1759  Autumn
# 169  Mimico (includes Humber Bay Shores) (17)      D22      1768  Autumn
# 206                       South Parkdale (85)      D11      1361  Spring
# 207                       South Parkdale (85)      D11      1369  Spring
# 208                       South Parkdale (85)      D11      1382  Spring
# 209                       South Parkdale (85)      D11      1388  Spring
# 210                       South Parkdale (85)      D11      1395  Spring
#
#      Year  Month  Day  ACC_NUM
# 31   2006      1   29      NaN
# 32   2006      1   29      NaN
# 45   2006      3    6      NaN
# 46   2006      3    6      NaN
# 47   2006      3    6      NaN
# 48   2006      3    6      NaN
# 49   2006      3    6      NaN
# 50   2006      3    6      NaN
# 51   2006      3    6      NaN
# 52   2006      3    8      NaN
# 53   2006      3    8      NaN
# 54   2006      3    8      NaN
# 55   2006      3    8      NaN
# 56   2006      3    8      NaN
# 96   2006      5   30      NaN
# 120  2006      7   30      NaN
# 149  2006      8   27      NaN
# 150  2006      8   27      NaN
# 161  2006     10   18      NaN
# 164  2006     11   11      NaN
# 165  2006     11   11      NaN
# 166  2006     11   11      NaN
# 167  2006     11   11      NaN
# 168  2006     11   11      NaN
# 169  2006     11   11      NaN
# 206  2007      3    6      NaN
# 207  2007      3    6      NaN
# 208  2007      3    6      NaN
# 209  2007      3    6      NaN
# 210  2007      3    6      NaN

# %%
# !pip install klib
# Out:
# Requirement already satisfied: klib in c:\users\rajgo\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in c:\users\rajgo\anaconda3\lib\site-packages (from klib) (3.1.3)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.3 in c:\users\rajgo\anaconda3\lib\site-packages (from klib) (3.8.0)
# Requirement already satisfied: numpy<2.0.0,>=1.16.3 in c:\users\rajgo\anaconda3\lib\site-packages (from klib) (1.26.4)
# Requirement already satisfied: pandas<3.0,>=1.2 in c:\users\rajgo\anaconda3\lib\site-packages (from klib) (2.1.4)
# Requirement already satisfied: plotly<6.0.0,>=5.2.2 in c:\users\rajgo\anaconda3\lib\site-packages (from klib) (5.9.0)
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in c:\users\rajgo\anaconda3\lib\site-packages (from klib) (1.11.4)
# Requirement already satisfied: screeninfo<0.9.0,>=0.8.1 in c:\users\rajgo\anaconda3\lib\site-packages (from klib) (0.8.1)
# Requirement already satisfied: seaborn>=0.11.2 in c:\users\rajgo\anaconda3\lib\site-packages (from klib) (0.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rajgo\anaconda3\lib\site-packages (from Jinja2<4.0.0,>=3.0.3->klib) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajgo\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajgo\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajgo\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rajgo\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajgo\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rajgo\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rajgo\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajgo\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajgo\anaconda3\lib\site-packages (from pandas<3.0,>=1.2->klib) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rajgo\anaconda3\lib\site-packages (from pandas<3.0,>=1.2->klib) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\rajgo\anaconda3\lib\site-packages (from plotly<6.0.0,>=5.2.2->klib) (8.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\rajgo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib) (1.16.0)

# %%
import klib

# %%
df.dtypes
# Out:
# INDEX_                             int64
# ACCNUM                           float64
# YEAR                               int64
# DATE                 datetime64[ns, UTC]
# TIME                               int64
# STREET1                           object
# STREET2                           object
# OFFSET                            object
# ROAD_CLASS                        object
# DISTRICT                          object
# WARDNUM                            int64
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCCOORD                          object
# ACCLOC                            object
# TRAFFCTL                          object
# VISIBILITY                        object
# LIGHT                             object
# RDSFCOND                          object
# ACCLASS                           object
# IMPACTYPE                         object
# INVTYPE                           object
# INVAGE                            object
# INJURY                            object
# FATAL_NO                         float64
# INITDIR                           object
# VEHTYPE                           object
# MANOEUVER                         object
# DRIVACT                           object
# DRIVCOND                          object
# PEDTYPE                           object
# PEDACT                            object
# PEDCOND                           object
# CYCLISTYPE                        object
# CYCACT                            object
# CYCCOND                           object
# PEDESTRIAN                        object
# CYCLIST                           object
# AUTOMOBILE                        object
# MOTORCYCLE                        object
# TRUCK                             object
# TRSN_CITY_VEH                     object
# EMERG_VEH                         object
# PASSENGER                         object
# SPEEDING                          object
# AG_DRIV                           object
# REDLIGHT                          object
# ALCOHOL                           object
# DISABILITY                        object
# HOOD_158                          object
# NEIGHBOURHOOD_158                 object
# HOOD_140                          object
# NEIGHBOURHOOD_140                 object
# DIVISION                          object
# ObjectId                           int64
# SEASON                            object
# Year                               int32
# Month                              int32
# Day                                int32
# ACC_NUM                          float64
# dtype: object

# %%
klib.convert_datatypes(df)
# Out:
#          INDEX_    ACCNUM  YEAR                      DATE  TIME  \
# 0       3363207  882024.0  2006 2006-01-07 05:00:00+00:00  2325
# 1       3363208  882024.0  2006 2006-01-07 05:00:00+00:00  2325
# 2       3363209  882024.0  2006 2006-01-07 05:00:00+00:00  2325
# 3       3363414  882174.0  2006 2006-01-09 05:00:00+00:00  1435
# 4       3363415  882174.0  2006 2006-01-09 05:00:00+00:00  1435
# ...         ...       ...   ...                       ...   ...
# 14995  81474608       NaN  2018 2018-04-26 04:00:00+00:00  1942
# 14996  81474609       NaN  2018 2018-04-26 04:00:00+00:00  1942
# 14997  81474610       NaN  2018 2018-04-26 04:00:00+00:00  1942
# 14998  81474611       NaN  2018 2018-04-26 04:00:00+00:00  1942
# 14999  81474612       NaN  2018 2018-04-26 04:00:00+00:00  1942
#
#              STREET1        STREET2 OFFSET      ROAD_CLASS        DISTRICT  \
# 0      STEELES AVE E  NINTH LINE ST    NaN  Minor Arterial     Scarborough
# 1      STEELES AVE E  NINTH LINE ST    NaN  Minor Arterial     Scarborough
# 2      STEELES AVE E  NINTH LINE ST    NaN  Minor Arterial     Scarborough
# 3         KENNEDY RD  GLAMORGAN AVE    NaN  Major Arterial     Scarborough
# 4         KENNEDY RD  GLAMORGAN AVE    NaN  Major Arterial     Scarborough
# ...              ...            ...    ...             ...             ...
# 14995  ISLINGTON AVE      ALBION RD    NaN  Major Arterial  Etobicoke York
# 14996  ISLINGTON AVE      ALBION RD    NaN  Major Arterial  Etobicoke York
# 14997  ISLINGTON AVE      ALBION RD    NaN  Major Arterial  Etobicoke York
# 14998  ISLINGTON AVE      ALBION RD    NaN  Major Arterial  Etobicoke York
# 14999  ISLINGTON AVE      ALBION RD    NaN  Major Arterial  Etobicoke York
#
#        ...             NEIGHBOURHOOD_158  HOOD_140  \
# 0      ...           Morningside Heights       131
# 1      ...           Morningside Heights       131
# 2      ...           Morningside Heights       131
# 3      ...                   Dorset Park       126
# 4      ...                   Dorset Park       126
# ...    ...                           ...       ...
# 14995  ...  Thistletown-Beaumond Heights         3
# 14996  ...  Thistletown-Beaumond Heights         3
# 14997  ...  Thistletown-Beaumond Heights         3
# 14998  ...  Thistletown-Beaumond Heights         3
# 14999  ...  Thistletown-Beaumond Heights         3
#
#                       NEIGHBOURHOOD_140 DIVISION ObjectId  SEASON  Year Month  \
# 0                           Rouge (131)      D42      167  Winter  2006     1
# 1                           Rouge (131)      D42      171  Winter  2006     1
# 2                           Rouge (131)      D42      173  Winter  2006     1
# 3                     Dorset Park (126)      D41      309  Winter  2006     1
# 4                     Dorset Park (126)      D41      314  Winter  2006     1
# ...                                 ...      ...      ...     ...   ...   ...
# 14995  Thistletown-Beaumond Heights (3)      D23    14996  Spring  2018     4
# 14996  Thistletown-Beaumond Heights (3)      D23    14997  Spring  2018     4
# 14997  Thistletown-Beaumond Heights (3)      D23    14998  Spring  2018     4
# 14998  Thistletown-Beaumond Heights (3)      D23    14999  Spring  2018     4
# 14999  Thistletown-Beaumond Heights (3)      D23    15000  Spring  2018     4
#
#       Day ACC_NUM
# 0       7  4477.0
# 1       7  4477.0
# 2       7  4477.0
# 3       9  2246.0
# 4       9  2246.0
# ...    ..     ...
# 14995  26  3679.0
# 14996  26  3679.0
# 14997  26  3679.0
# 14998  26  3679.0
# 14999  26  3679.0
#
# [15000 rows x 60 columns]

# %%
df.dtypes
# Out:
# INDEX_                             int64
# ACCNUM                           float64
# YEAR                               int64
# DATE                 datetime64[ns, UTC]
# TIME                               int64
# STREET1                           object
# STREET2                           object
# OFFSET                            object
# ROAD_CLASS                        object
# DISTRICT                          object
# WARDNUM                            int64
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCCOORD                          object
# ACCLOC                            object
# TRAFFCTL                          object
# VISIBILITY                        object
# LIGHT                             object
# RDSFCOND                          object
# ACCLASS                           object
# IMPACTYPE                         object
# INVTYPE                           object
# INVAGE                            object
# INJURY                            object
# FATAL_NO                         float64
# INITDIR                           object
# VEHTYPE                           object
# MANOEUVER                         object
# DRIVACT                           object
# DRIVCOND                          object
# PEDTYPE                           object
# PEDACT                            object
# PEDCOND                           object
# CYCLISTYPE                        object
# CYCACT                            object
# CYCCOND                           object
# PEDESTRIAN                        object
# CYCLIST                           object
# AUTOMOBILE                        object
# MOTORCYCLE                        object
# TRUCK                             object
# TRSN_CITY_VEH                     object
# EMERG_VEH                         object
# PASSENGER                         object
# SPEEDING                          object
# AG_DRIV                           object
# REDLIGHT                          object
# ALCOHOL                           object
# DISABILITY                        object
# HOOD_158                          object
# NEIGHBOURHOOD_158                 object
# HOOD_140                          object
# NEIGHBOURHOOD_140                 object
# DIVISION                          object
# ObjectId                           int64
# SEASON                            object
# Year                               int32
# Month                              int32
# Day                                int32
# ACC_NUM                          float64
# dtype: object

# %%
# # Find null values in the 'ACC_NUM' column
# null_values_indices = df[df['ACC_NUM'].isnull()].index

# # Generate a sequence starting from 4545
# sequence = range(4545, 4545 + len(null_values_indices))

# # Fill null values with the generated sequence
# df.loc[null_values_indices, 'ACC_NUM'] = sequence

# # Display the DataFrame with filled null values
# df["ACC_NUM"].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# INDEX_                   0
# ACCNUM                3698
# YEAR                     0
# DATE                     0
# TIME                     0
# STREET1                  0
# STREET2               1343
# OFFSET               13072
# ROAD_CLASS             357
# DISTRICT                14
# WARDNUM                  0
# LATITUDE                 0
# LONGITUDE                0
# LOCCOORD                90
# ACCLOC                5450
# TRAFFCTL                29
# VISIBILITY              14
# LIGHT                    0
# RDSFCOND                19
# ACCLASS                  0
# IMPACTYPE                0
# INVTYPE                 10
# INVAGE                   0
# INJURY                7189
# FATAL_NO             14407
# INITDIR               4498
# VEHTYPE               2055
# MANOEUVER             6514
# DRIVACT               7575
# DRIVCOND              7579
# PEDTYPE              12540
# PEDACT               12550
# PEDCOND              12555
# CYCLISTYPE           14365
# CYCACT               14379
# CYCCOND              14380
# PEDESTRIAN            9034
# CYCLIST              13422
# AUTOMOBILE            1328
# MOTORCYCLE           13838
# TRUCK                14067
# TRSN_CITY_VEH        14077
# EMERG_VEH            14981
# PASSENGER             9367
# SPEEDING             13002
# AG_DRIV               7304
# REDLIGHT             13725
# ALCOHOL              14328
# DISABILITY           14580
# HOOD_158                 0
# NEIGHBOURHOOD_158        0
# HOOD_140                 0
# NEIGHBOURHOOD_140        0
# DIVISION                 0
# ObjectId                 0
# SEASON                   0
# Year                     0
# Month                    0
# Day                      0
# ACC_NUM               1544
# dtype: int64
