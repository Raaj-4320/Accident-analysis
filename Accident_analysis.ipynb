# %% [markdown]
# <a href="https://colab.research.google.com/github/Raaj-4320/Accident-analysis/blob/EDA/Accident_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', None)
import plotly.graph_objs as go
import plotly.express as px
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("drive/MyDrive/Datasets/Train.csv")

# %% [markdown]
# # #EDA

# %% [markdown]
# # Checking for number of missing and unique values in dataset

# %%
# First result: Total null values for each feature
null_counts = df.isnull().sum()
null_df = pd.DataFrame(null_counts, columns=["Missing Values"])

# Second result: Total unique values for each feature
unique_values = df.nunique().reset_index()
unique_values.columns = ["Feature", "Unique Values"]

# Combine the two DataFrames
combined_df = pd.merge(unique_values, null_df, left_on="Feature", right_index=True)

# Display the combined DataFrame
print(combined_df)
# Out:
#               Feature  Unique Values  Missing Values
# 0              INDEX_          15000               0
# 1              ACCNUM           3822            3698
# 2                YEAR             13               0
# 3                DATE           3082               0
# 4                TIME           1276               0
# 5             STREET1           1547               0
# 6             STREET2           2344            1343
# 7              OFFSET            339           13072
# 8          ROAD_CLASS              9             357
# 9            DISTRICT              4              14
# 10            WARDNUM             71               0
# 11           LATITUDE           3475               0
# 12          LONGITUDE           3901               0
# 13           LOCCOORD              7              90
# 14             ACCLOC              9            5450
# 15           TRAFFCTL             10              29
# 16         VISIBILITY              8              14
# 17              LIGHT              9               0
# 18           RDSFCOND              9              19
# 19            ACCLASS              2               0
# 20          IMPACTYPE             10               0
# 21            INVTYPE             18              10
# 22             INVAGE             21               0
# 23             INJURY              5            1606
# 24           FATAL_NO             78           14407
# 25            INITDIR              5            4498
# 26            VEHTYPE             27            2055
# 27          MANOEUVER             16            6514
# 28            DRIVACT             13            7575
# 29           DRIVCOND             10            7579
# 30            PEDTYPE             16           12540
# 31             PEDACT             15           12550
# 32            PEDCOND             10           12555
# 33         CYCLISTYPE             22           14365
# 34             CYCACT             11           14379
# 35            CYCCOND             10           14380
# 36         PEDESTRIAN              1            9034
# 37            CYCLIST              1           13422
# 38         AUTOMOBILE              1            1328
# 39         MOTORCYCLE              1           13838
# 40              TRUCK              1           14067
# 41      TRSN_CITY_VEH              1           14077
# 42          EMERG_VEH              1           14981
# 43          PASSENGER              1            9367
# 44           SPEEDING              1           13002
# 45            AG_DRIV              1            7304
# 46           REDLIGHT              1           13725
# 47            ALCOHOL              1           14328
# 48         DISABILITY              1           14580
# 49           HOOD_158            159               0
# 50  NEIGHBOURHOOD_158            159               0
# 51           HOOD_140            141               0
# 52  NEIGHBOURHOOD_140            141               0
# 53           DIVISION             17               0
# 54           ObjectId          15000               0

# %% [markdown]
# # #INDEX_

# %%
# Removing INDEX_ column as it has no relavance to the analysis

# %%
df.drop('INDEX_', axis=1, inplace=True)

# %% [markdown]
# # #ACCNUM

# %%
# Removing those ACCCNUMS which are non-fatal

to_drop = df[(df['ACCNUM'].isna()) & (df['ACCLASS'] == 'Non-Fatal Injury') ].index

df = df.drop(to_drop, axis=0)
# to_drop

# %%
'''
ACCNUM is an important becuase it is representative of one accident incident but, we have null values in the columns
So, we are proceeding with creating new ACC_NUM of our own, wich will be decided on the parameters likem, TIME, DATE, YEAR
and STEET1, we will give 1 unique number to those records which have same data in these columns it means that if parties
involved in an accident has same TIME, DATE, YEAR and STREET1, it determines that the other person matching the
same parameteres was involved in the same accident and one unique number will be allocated to that accident.

Which is ultimately same as organicaly given accident id.
'''
# Out:
# '\nACCNUM is an important becuase it is representative of one accident incident but, we have null values in the columns \nSo, we are proceeding with creating new ACC_NUM of our own, wich will be decided on the parameters likem, TIME, DATE, YEAR \nand STEET1, we will give 1 unique number to those records which have same data in these columns it means that if parties \ninvolved in an accident has same TIME, DATE, YEAR and STREET1, it determines that the other person matching the \nsame parameteres was involved in the same accident and one unique number will be allocated to that accident.\n\nWhich is ultimately same as organicaly given accident id.\n'

# %%
# Impute those ACCNUM nulls which ahve ACCLASS as FATAL
one_accident = df[df.duplicated(subset=['YEAR','DATE','TIME','STREET1'], keep=False)]

# Group by the condition and assign a unique index ID
one_accident['ACC_NUM'] = one_accident.groupby(['YEAR','DATE','TIME','STREET1']).ngroup()

# Merge the unique index IDs back to the original DataFrame
df = pd.merge(df, one_accident[['ACC_NUM']], left_index=True, right_index=True, how='left')
# Out:
# <ipython-input-334-b6bd90eac855>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_accident['ACC_NUM'] = one_accident.groupby(['YEAR','DATE','TIME','STREET1']).ngroup()

# %%
'''
Some records will left as it is, as it doesn't match with our condition, becase those accidents have no other records
matching the requirement we provided so, if they are FATAL then they are important becuase we have less values for FATAL which
our target variable, but if we have Non-Fatal Injury from ACCLASS then we can drop those records because, we hace more than 7x
data of it as compared to FATAL.
'''
# Out:
# "\nSome records will left as it is, as it doesn't match with our condition, becase those accidents have no other records\nmatching the requirement we provided so, if they are FATAL then they are important becuase we have less values for FATAL which \nour target variable, but if we have Non-Fatal Injury from ACCLASS then we can drop those records because, we hace more than 7x \ndata of it as compared to FATAL.\n"

# %%
df[(df["ACC_NUM"].isna()) & (df["ACCLASS"] == "Fatal")]
# Out:
#             ACCNUM  YEAR                    DATE  TIME  \
# 659       905761.0  2006  2006/05/30 04:00:00+00  2328
# 880       916024.0  2006  2006/07/30 04:00:00+00  2155
# 1141      930890.0  2006  2006/10/18 04:00:00+00  2136
# 2558      987376.0  2007  2007/08/30 04:00:00+00  2252
# 2916      987500.0  2007  2007/09/02 04:00:00+00    48
# 3903     1039861.0  2008  2008/05/24 04:00:00+00    30
# 3990     1061341.0  2008  2008/09/28 04:00:00+00   545
# 7524     1276186.0  2012  2012/01/20 05:00:00+00  2214
# 8694     1290105.0  2012  2012/04/20 04:00:00+00  1447
# 9470     1361106.0  2013  2013/06/16 04:00:00+00   616
# 10355  131058335.0  2013  2013/11/29 05:00:00+00   558
# 10380  141649049.0  2014  2014/03/06 05:00:00+00   735
# 10919  142300273.0  2014  2014/06/16 04:00:00+00   827
# 11097          NaN  2015  2015/05/27 04:00:00+00  2120
# 11303          NaN  2015  2015/01/11 05:00:00+00   353
# 11478          NaN  2015  2015/06/13 04:00:00+00   300
# 11501          NaN  2015  2015/09/06 04:00:00+00  1034
# 11562  143022510.0  2014  2014/10/01 04:00:00+00  1620
# 11572  143234908.0  2014  2014/11/04 05:00:00+00   807
# 11918  143357519.0  2014  2014/11/24 05:00:00+00   350
# 11944          NaN  2015  2015/04/01 04:00:00+00  2308
# 12291          NaN  2015  2015/11/14 05:00:00+00   825
# 12530          NaN  2016  2016/07/12 04:00:00+00  1710
# 12578          NaN  2016  2016/01/08 05:00:00+00   520
# 12807          NaN  2016  2016/03/09 05:00:00+00  1835
# 12913          NaN  2016  2016/05/30 04:00:00+00  1728
# 13614          NaN  2016  2016/10/27 04:00:00+00  1549
# 13655          NaN  2016  2016/10/30 04:00:00+00   227
# 13667          NaN  2016  2016/10/31 04:00:00+00   257
# 13691          NaN  2017  2017/05/16 04:00:00+00  1135
# 13776          NaN  2017  2017/08/26 04:00:00+00  1055
# 13813          NaN  2017  2017/01/21 05:00:00+00    40
# 13871          NaN  2017  2017/05/24 04:00:00+00  1815
# 14347          NaN  2017  2017/12/17 05:00:00+00    41
# 14385          NaN  2018  2018/01/01 05:00:00+00   125
# 14562          NaN  2018  2018/02/17 05:00:00+00  2319
# 14588          NaN  2018  2018/07/25 04:00:00+00    45
# 14623          NaN  2018  2018/07/29 04:00:00+00  1029
# 14878          NaN  2018  2018/04/21 04:00:00+00  2341
#
#                       STREET1                     STREET2         OFFSET  \
# 659        ROSEDALE VALLEY RD                 BAYVIEW AVE            NaN
# 880    F G GARDINER XY Ramp W  GARDINER W S KINGSWAY RAMP            NaN
# 1141            OLD FINCH AVE                   REESOR RD            NaN
# 2558       F G GARDINER XY  W                 JAMESON AVE            NaN
# 2916           SHEPPARD AVE W                 SENTINEL RD            NaN
# 3903             BAYVIEW Aven                  BLOOR Ramp            NaN
# 3990               WILSON AVE              HIGHWAY 400  S            NaN
# 7524           SENECA HILL DR                DON MILLS RD            NaN
# 8694    DON VALLEY PARKWAY  N                GERRARD ST E            NaN
# 9470         JOE SHUSTER  WAY                   KING ST W            NaN
# 10355  1491 LAKE SHORE BLVD W                         NaN            NaN
# 10380      PRINCE EDWARD DR N                   SHAND AVE            NaN
# 10919           BROADVIEW AVE               FAIRVIEW BLVD            NaN
# 11097              TANGAMO RD                 MOFORD CRES  17 m North of
# 11303       477 BROADVIEW AVE                         NaN            NaN
# 11478      F G GARDINER XY  W               ROYAL YORK RD            NaN
# 11501       LAKE SHORE BLVD W                 JAMESON AVE    1 m West of
# 11562             35 IRWIN RD                         NaN            NaN
# 11572           ORTON PARK RD                    SLAN AVE            NaN
# 11918   DON VALLEY PARKWAY  N                LEASIDE BDGE            NaN
# 11944      F G GARDINER XY  W                STRACHAN AVE            NaN
# 12291        1996 BATHURST ST                         NaN            NaN
# 12530           BIRMINGHAM ST               ELSINORE PATH            NaN
# 12578            BROWN S LINE           LAKE SHORE BLVD W  30 m North of
# 12807           STEELES AVE W               ISLINGTON AVE            NaN
# 12913             4 EWART AVE                         NaN            NaN
# 13614               CHERRY ST                   POLSON ST            NaN
# 13655            PHARMACY AVE              EGLINTON AVE E            NaN
# 13667      F G GARDINER XY  E                 JAMESON AVE            NaN
# 13691         95 ELLESMERE RD                         NaN            NaN
# 13776     3738 ST CLAIR AVE E                         NaN            NaN
# 13813             BROWNS LINE  LAKESHORE W BROWNS LI RAMP     20 m North
# 13871  1395 LAKE SHORE BLVD W                         NaN            NaN
# 14347             KINGSTON RD              GUILDWOOD PKWY            NaN
# 14385             BAYVIEW AVE                  POTTERY RD     403 m N of
# 14562        3230 BAYVIEW AVE                         NaN            NaN
# 14588               DORIS AVE                  HOLMES AVE     42 m South
# 14623         144 NORSEMAN ST                         NaN            NaN
# 14878              SEWELLS RD                HUPFIELD TRL            NaN
#
#            ROAD_CLASS               DISTRICT  WARDNUM   LATITUDE  LONGITUDE  \
# 659    Minor Arterial  Toronto and East York     1113  43.671645 -79.366090
# 880               NaN  Toronto and East York        4  43.634645 -79.471590
# 1141        Collector            Scarborough       25  43.824745 -79.190590
# 2558              NaN  Toronto and East York        4  43.632745 -79.433790
# 2916   Major Arterial             North York        6  43.743645 -79.491790
# 3903              NaN  Toronto and East York       11  43.677146 -79.367893
# 3990   Major Arterial         Etobicoke York        7  43.718145 -79.521090
# 7524        Collector             North York       17  43.790045 -79.355190
# 8694              NaN  Toronto and East York       14  43.665145 -79.355890
# 9470            Local  Toronto and East York       10  43.640547 -79.423999
# 10355  Major Arterial  Toronto and East York        4  43.637614 -79.447742
# 10380       Collector         Etobicoke York        3  43.657290 -79.509113
# 10919  Minor Arterial  Toronto and East York       14  43.675116 -79.357845
# 11097           Local         Etobicoke York        2  43.690470 -79.559459
# 11303  Minor Arterial  Toronto and East York       14  43.669097 -79.352985
# 11478             NaN         Etobicoke York        3  43.622645 -79.502467
# 11501  Major Arterial  Toronto and East York        4  43.633349 -79.435138
# 11562           Local         Etobicoke York        1  43.725997 -79.555110
# 11572  Minor Arterial            Scarborough       24  43.777968 -79.211902
# 11918  Major Arterial  Toronto and East York       14  43.697508 -79.349437
# 11944             NaN  Toronto and East York       10  43.637427 -79.412120
# 12291  Major Arterial  Toronto and East York       12  43.699485 -79.424945
# 12530       Collector         Etobicoke York        3  43.602278 -79.510753
# 12578  Major Arterial         Etobicoke York        3  43.593039 -79.541560
# 12807  Major Arterial         Etobicoke York        7  43.764662 -79.573322
# 12913           Local         Etobicoke York        5  43.688113 -79.467433
# 13614       Collector  Toronto and East York       14  43.641406 -79.349178
# 13655  Major Arterial            Scarborough     2120  43.725642 -79.297504
# 13667             NaN  Toronto and East York        4  43.633078 -79.435222
# 13691  Major Arterial            Scarborough       21  43.758727 -79.311122
# 13776  Minor Arterial            Scarborough       20  43.720442 -79.243045
# 13813  Major Arterial         Etobicoke York        3  43.592673 -79.542079
# 13871  Major Arterial  Toronto and East York        4  43.635432 -79.441371
# 14347  Major Arterial            Scarborough       24  43.749583 -79.205920
# 14385  Major Arterial             North York     1115  43.692008 -79.361987
# 14562  Major Arterial             North York     1817  43.788287 -79.392772
# 14588  Minor Arterial             North York       18  43.777663 -79.413097
# 14623       Collector         Etobicoke York        3  43.633887 -79.520046
# 14878  Minor Arterial            Scarborough       25  43.814105 -79.213535
#
#                   LOCCOORD                ACCLOC        TRAFFCTL  \
# 659              Mid-Block                   NaN      No Control
# 880    Exit Ramp Westbound                   NaN      No Control
# 1141             Mid-Block                   NaN      No Control
# 2558             Mid-Block                   NaN      No Control
# 2916          Intersection                   NaN  Traffic Signal
# 3903             Mid-Block                   NaN      No Control
# 3990          Intersection       At Intersection      No Control
# 7524             Mid-Block                   NaN      No Control
# 8694             Mid-Block                   NaN      No Control
# 9470             Mid-Block                   NaN      No Control
# 10355            Mid-Block                   NaN      No Control
# 10380         Intersection                   NaN      No Control
# 10919            Mid-Block                   NaN      No Control
# 11097         Intersection      Non Intersection       Stop Sign
# 11303            Mid-Block                   NaN      No Control
# 11478            Mid-Block                   NaN      No Control
# 11501            Mid-Block      Non Intersection      No Control
# 11562            Mid-Block                   NaN      No Control
# 11572            Mid-Block                   NaN      No Control
# 11918            Mid-Block                   NaN      No Control
# 11944            Mid-Block                   NaN      No Control
# 12291            Mid-Block      Non Intersection      No Control
# 12530         Intersection       At Intersection      No Control
# 12578            Mid-Block      Non Intersection      No Control
# 12807            Mid-Block                   NaN      No Control
# 12913         Intersection      Non Intersection      No Control
# 13614            Mid-Block    Overpass or Bridge      No Control
# 13655         Intersection  Intersection Related      No Control
# 13667            Mid-Block      Non Intersection      No Control
# 13691            Mid-Block      Non Intersection      No Control
# 13776            Mid-Block      Non Intersection      No Control
# 13813            Mid-Block      Non Intersection      No Control
# 13871            Mid-Block      Non Intersection      No Control
# 14347         Intersection       At Intersection  Traffic Signal
# 14385            Mid-Block      Non Intersection      No Control
# 14562            Mid-Block      Non Intersection      No Control
# 14588            Mid-Block      Non Intersection      No Control
# 14623            Mid-Block      Non Intersection      No Control
# 14878            Mid-Block      Non Intersection      No Control
#
#                    VISIBILITY             LIGHT     RDSFCOND ACCLASS  \
# 659                     Clear              Dark          Dry   Fatal
# 880                     Clear              Dark          Dry   Fatal
# 1141                    Clear              Dark          Dry   Fatal
# 2558                    Clear              Dark          Dry   Fatal
# 2916                    Clear              Dark          Dry   Fatal
# 3903                    Clear              Dark          Dry   Fatal
# 3990                    Clear              Dark          Wet   Fatal
# 7524                     Snow              Dark  Packed Snow   Fatal
# 8694                    Clear          Daylight          Dry   Fatal
# 9470                     Rain          Daylight          Wet   Fatal
# 10355                   Clear  Dawn, artificial          Dry   Fatal
# 10380                    Snow          Daylight        Slush   Fatal
# 10919                    Rain          Daylight          Wet   Fatal
# 11097                   Clear  Dark, artificial          Dry   Fatal
# 11303                   Clear  Dark, artificial          Dry   Fatal
# 11478                    Rain              Dark          Wet   Fatal
# 11501                   Clear          Daylight          Dry   Fatal
# 11562                   Clear          Daylight          Wet   Fatal
# 11572                   Clear          Daylight          Dry   Fatal
# 11918                    Rain  Dark, artificial          Wet   Fatal
# 11944                   Clear  Dark, artificial          Dry   Fatal
# 12291                   Clear          Daylight          Dry   Fatal
# 12530                   Clear          Daylight          Dry   Fatal
# 12578                   Clear  Dark, artificial          Wet   Fatal
# 12807                   Clear          Daylight          Dry   Fatal
# 12913                   Clear          Daylight          Dry   Fatal
# 13614                    Rain          Daylight          Wet   Fatal
# 13655                   Clear              Dark          Dry   Fatal
# 13667                   Clear              Dark          Dry   Fatal
# 13691                   Clear          Daylight          Dry   Fatal
# 13776                   Clear          Daylight          Dry   Fatal
# 13813  Fog, Mist, Smoke, Dust  Dark, artificial          Wet   Fatal
# 13871                   Clear          Daylight          Dry   Fatal
# 14347                   Other              Dark        Other   Fatal
# 14385                   Clear  Dark, artificial          Dry   Fatal
# 14562                     NaN              Dark          NaN   Fatal
# 14588                   Clear  Dark, artificial          Wet   Fatal
# 14623                   Clear          Daylight          Dry   Fatal
# 14878                   Clear  Dark, artificial          Dry   Fatal
#
#                    IMPACTYPE            INVTYPE    INVAGE INJURY  FATAL_NO  \
# 659                SMV Other  Motorcycle Driver  25 to 29  Fatal       NaN
# 880                SMV Other  Motorcycle Driver  20 to 24  Fatal       NaN
# 1141               SMV Other  Motorcycle Driver  20 to 24  Fatal       NaN
# 2558               SMV Other  Motorcycle Driver  25 to 29  Fatal       NaN
# 2916               SMV Other             Driver  40 to 44  Fatal       NaN
# 3903               SMV Other  Motorcycle Driver  25 to 29  Fatal      21.0
# 3990               SMV Other             Driver  55 to 59  Fatal      42.0
# 7524               SMV Other             Driver  85 to 89  Fatal       4.0
# 8694               SMV Other  Motorcycle Driver  35 to 39  Fatal      11.0
# 9470               SMV Other             Driver  40 to 44  Fatal      17.0
# 10355              SMV Other             Driver  25 to 29  Fatal      58.0
# 10380              SMV Other             Driver  50 to 54  Fatal       6.0
# 10919              SMV Other  Motorcycle Driver  45 to 49  Fatal      12.0
# 11097              SMV Other             Driver  15 to 19  Fatal      24.0
# 11303              SMV Other             Driver  20 to 24  Fatal       1.0
# 11478              SMV Other             Driver  20 to 24  Fatal      30.0
# 11501              SMV Other  Motorcycle Driver  55 to 59  Fatal      42.0
# 11562              SMV Other  Motorcycle Driver  20 to 24  Fatal      31.0
# 11572              SMV Other             Driver  25 to 29  Fatal      37.0
# 11918              SMV Other             Driver  20 to 24  Fatal      43.0
# 11944              SMV Other  Motorcycle Driver   unknown  Fatal      15.0
# 12291  Pedestrian Collisions         Pedestrian  85 to 89  Fatal      65.0
# 12530              SMV Other             Driver  55 to 59  Fatal      46.0
# 12578              SMV Other             Driver  40 to 44  Fatal       2.0
# 12807               Rear End  Motorcycle Driver  25 to 29  Fatal      16.0
# 12913                  Other             Driver  65 to 69  Fatal      34.0
# 13614              SMV Other             Driver  50 to 54  Fatal      66.0
# 13655              SMV Other             Driver  30 to 34  Fatal      67.0
# 13667              SMV Other             Driver  25 to 29  Fatal      68.0
# 13691              SMV Other             Driver  80 to 84  Fatal      23.0
# 13776              SMV Other             Driver  30 to 34  Fatal      37.0
# 13813              SMV Other             Driver  20 to 24  Fatal       3.0
# 13871     Cyclist Collisions            Cyclist    5 to 9  Fatal      24.0
# 14347              SMV Other             Driver  50 to 54  Fatal      58.0
# 14385              SMV Other             Driver  35 to 39  Fatal       1.0
# 14562              SMV Other             Driver  45 to 49  Fatal      10.0
# 14588              SMV Other             Driver  20 to 24  Fatal      36.0
# 14623              SMV Other  Motorcycle Driver  45 to 49  Fatal      38.0
# 14878              SMV Other             Driver  25 to 29  Fatal      20.0
#
#        INITDIR                    VEHTYPE  \
# 659       East                 Motorcycle
# 880       West                 Motorcycle
# 1141      West                 Motorcycle
# 2558      West                 Motorcycle
# 2916      East  Automobile, Station Wagon
# 3903     North                 Motorcycle
# 3990      East  Automobile, Station Wagon
# 7524      West  Automobile, Station Wagon
# 8694     North                 Motorcycle
# 9470      East  Automobile, Station Wagon
# 10355     East  Automobile, Station Wagon
# 10380    South  Automobile, Station Wagon
# 10919    North                 Motorcycle
# 11097    South  Automobile, Station Wagon
# 11303    South  Automobile, Station Wagon
# 11478     West  Automobile, Station Wagon
# 11501     East                 Motorcycle
# 11562     East                 Motorcycle
# 11572    North  Automobile, Station Wagon
# 11918    North  Automobile, Station Wagon
# 11944     West                 Motorcycle
# 12291      NaN  Automobile, Station Wagon
# 12530     West  Automobile, Station Wagon
# 12578    South  Automobile, Station Wagon
# 12807     West                 Motorcycle
# 12913  Unknown  Automobile, Station Wagon
# 13614    North  Automobile, Station Wagon
# 13655    North  Automobile, Station Wagon
# 13667     East  Automobile, Station Wagon
# 13691     East  Automobile, Station Wagon
# 13776     East  Automobile, Station Wagon
# 13813    South               Delivery Van
# 13871     West                    Bicycle
# 14347     East  Automobile, Station Wagon
# 14385    South  Automobile, Station Wagon
# 14562     West  Automobile, Station Wagon
# 14588    North  Automobile, Station Wagon
# 14623     East                 Motorcycle
# 14878     East  Automobile, Station Wagon
#
#                                  MANOEUVER                       DRIVACT  \
# 659                            Going Ahead                  Lost control
# 880                            Going Ahead                  Lost control
# 1141                           Going Ahead                  Lost control
# 2558                           Going Ahead                  Lost control
# 2916                           Going Ahead                  Lost control
# 3903                           Going Ahead         Exceeding Speed Limit
# 3990                           Going Ahead         Exceeding Speed Limit
# 7524                           Going Ahead                  Lost control
# 8694                           Going Ahead         Exceeding Speed Limit
# 9470                           Going Ahead                         Other
# 10355                          Going Ahead                  Lost control
# 10380  Pulling Onto Shoulder or towardCurb                  Lost control
# 10919                          Going Ahead              Driving Properly
# 11097                          Going Ahead                         Other
# 11303                          Going Ahead                  Lost control
# 11478                          Going Ahead         Exceeding Speed Limit
# 11501                          Going Ahead                  Lost control
# 11562                          Going Ahead                  Lost control
# 11572                          Going Ahead                  Lost control
# 11918                          Going Ahead         Exceeding Speed Limit
# 11944                          Going Ahead         Exceeding Speed Limit
# 12291                                  NaN                           NaN
# 12530                          Going Ahead                  Lost control
# 12578                          Going Ahead  Speed too Fast For Condition
# 12807                          Going Ahead  Speed too Fast For Condition
# 12913                            Reversing                         Other
# 13614                          Going Ahead                  Lost control
# 13655                          Going Ahead                  Lost control
# 13667                          Going Ahead                  Lost control
# 13691                          Going Ahead                  Lost control
# 13776                          Going Ahead                  Lost control
# 13813                          Going Ahead                  Lost control
# 13871                          Going Ahead                           NaN
# 14347                          Going Ahead         Exceeding Speed Limit
# 14385                          Going Ahead  Speed too Fast For Condition
# 14562                          Going Ahead         Exceeding Speed Limit
# 14588                          Going Ahead         Exceeding Speed Limit
# 14623                          Going Ahead                  Lost control
# 14878                          Going Ahead                  Lost control
#
#                              DRIVCOND                        PEDTYPE PEDACT  \
# 659                            Normal                            NaN    NaN
# 880                           Unknown                            NaN    NaN
# 1141                      Inattentive                            NaN    NaN
# 2558                           Normal                            NaN    NaN
# 2916                          Unknown                            NaN    NaN
# 3903                          Unknown                            NaN    NaN
# 3990                Had Been Drinking                            NaN    NaN
# 7524                          Unknown                            NaN    NaN
# 8694                          Unknown                            NaN    NaN
# 9470                          Unknown                            NaN    NaN
# 10355                         Unknown                            NaN    NaN
# 10380                         Unknown                            NaN    NaN
# 10919                         Unknown                            NaN    NaN
# 11097                         Unknown                            NaN    NaN
# 11303                         Unknown                            NaN    NaN
# 11478                         Unknown                            NaN    NaN
# 11501                         Unknown                            NaN    NaN
# 11562                         Unknown                            NaN    NaN
# 11572                         Unknown                            NaN    NaN
# 11918       Ability Impaired, Alcohol                            NaN    NaN
# 11944                         Unknown                            NaN    NaN
# 12291                             NaN  Pedestrian hit at parking lot  Other
# 12530  Medical or Physical Disability                            NaN    NaN
# 12578                         Unknown                            NaN    NaN
# 12807                         Unknown                            NaN    NaN
# 12913                         Unknown                            NaN    NaN
# 13614                         Unknown                            NaN    NaN
# 13655               Had Been Drinking                            NaN    NaN
# 13667                         Unknown                            NaN    NaN
# 13691  Medical or Physical Disability                            NaN    NaN
# 13776         Ability Impaired, Drugs                            NaN    NaN
# 13813               Had Been Drinking                            NaN    NaN
# 13871                             NaN                            NaN    NaN
# 14347                         Unknown                            NaN    NaN
# 14385                         Unknown                            NaN    NaN
# 14562                         Unknown                            NaN    NaN
# 14588                         Unknown                            NaN    NaN
# 14623                         Unknown                            NaN    NaN
# 14878                         Unknown                            NaN    NaN
#
#       PEDCOND                                         CYCLISTYPE  \
# 659       NaN                                                NaN
# 880       NaN                                                NaN
# 1141      NaN                                                NaN
# 2558      NaN                                                NaN
# 2916      NaN                                                NaN
# 3903      NaN                                                NaN
# 3990      NaN                                                NaN
# 7524      NaN                                                NaN
# 8694      NaN                                                NaN
# 9470      NaN                                                NaN
# 10355     NaN                                                NaN
# 10380     NaN                                                NaN
# 10919     NaN                                                NaN
# 11097     NaN                                                NaN
# 11303     NaN                                                NaN
# 11478     NaN                                                NaN
# 11501     NaN                                                NaN
# 11562     NaN                                                NaN
# 11572     NaN                                                NaN
# 11918     NaN                                                NaN
# 11944     NaN                                                NaN
# 12291  Normal                                                NaN
# 12530     NaN                                                NaN
# 12578     NaN                                                NaN
# 12807     NaN                                                NaN
# 12913     NaN                                                NaN
# 13614     NaN                                                NaN
# 13655     NaN                                                NaN
# 13667     NaN                                                NaN
# 13691     NaN                                                NaN
# 13776     NaN                                                NaN
# 13813     NaN                                                NaN
# 13871     NaN  Insufficient information (to determine cyclist...
# 14347     NaN                                                NaN
# 14385     NaN                                                NaN
# 14562     NaN                                                NaN
# 14588     NaN                                                NaN
# 14623     NaN                                                NaN
# 14878     NaN                                                NaN
#
#              CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK  \
# 659             NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 880             NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 1141            NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 2558            NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 2916            NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 3903            NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 3990            NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 7524            NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 8694            NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 9470            NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 10355           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 10380           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 10919           NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 11097           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 11303           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 11478           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 11501           NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 11562           NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 11572           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 11918           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 11944           NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 12291           NaN     NaN        Yes     NaN        Yes        NaN   NaN
# 12530           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 12578           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 12807           NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 12913           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 13614           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 13655           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 13667           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 13691           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 13776           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 13813           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 13871  Lost control  Normal        NaN     Yes        NaN        NaN   NaN
# 14347           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 14385           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 14562           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 14588           NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 14623           NaN     NaN        NaN     NaN        NaN        Yes   NaN
# 14878           NaN     NaN        NaN     NaN        Yes        NaN   NaN
#
#       TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL  \
# 659             NaN       NaN       NaN      NaN     Yes      NaN     NaN
# 880             NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 1141            NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 2558            NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 2916            NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 3903            NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 3990            NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 7524            NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 8694            NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 9470            NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 10355           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 10380           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 10919           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 11097           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 11303           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 11478           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 11501           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 11562           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 11572           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 11918           NaN       NaN       NaN      Yes     Yes      NaN     Yes
# 11944           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 12291           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 12530           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 12578           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 12807           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 12913           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 13614           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 13655           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 13667           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 13691           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 13776           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 13813           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 13871           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 14347           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 14385           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 14562           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 14588           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 14623           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 14878           NaN       NaN       NaN      Yes     Yes      NaN     NaN
#
#       DISABILITY HOOD_158                 NEIGHBOURHOOD_158 HOOD_140  \
# 659          NaN       71   Cabbagetown-South St.James Town       71
# 880          NaN       85                    South Parkdale       85
# 1141         NaN      144               Morningside Heights      131
# 2558         NaN       85                    South Parkdale       85
# 2916         NaN      155                         Downsview       26
# 3903         NaN       98               Rosedale-Moore Park       98
# 3990         NaN      154          Oakdale-Beverley Heights       26
# 7524         NaN       47                Don Valley Village       47
# 8694         NaN       68                   North Riverdale       68
# 9470         NaN       85                    South Parkdale       85
# 10355        NaN       85                    South Parkdale       85
# 10380        NaN       15                    Kingsway South       15
# 10919        NaN       68                   North Riverdale       68
# 11097        NaN        7  Willowridge-Martingrove-Richview        7
# 11303        NaN       68                   North Riverdale       68
# 11478        NaN       16               Stonegate-Queensway       16
# 11501        NaN       85                    South Parkdale       85
# 11562        NaN        5                  Elms-Old Rexdale        5
# 11572        NaN      135                       Morningside      135
# 11918        NaN       58                     Old East York       58
# 11944        NaN      163         Fort York-Liberty Village       82
# 12291        NaN      101                 Forest Hill South      101
# 12530        Yes       18                       New Toronto       18
# 12578        NaN       19                       Long Branch       19
# 12807        NaN       21                     Humber Summit       21
# 12913        NaN      110          Keelesdale-Eglinton West      110
# 13614        NaN       70                   South Riverdale       70
# 13655        NaN      120               Clairlea-Birchmount      120
# 13667        NaN       85                    South Parkdale       85
# 13691        Yes      119                  Wexford/Maryvale      119
# 13776        NaN      123                        Cliffcrest      123
# 13813        NaN       19                       Long Branch       19
# 13871        NaN       85                    South Parkdale       85
# 14347        NaN      140                         Guildwood      140
# 14385        NaN       56                Leaside-Bennington       56
# 14562        NaN       49             Bayview Woods-Steeles       49
# 14588        NaN      151                       Yonge-Doris       51
# 14623        NaN      159             Etobicoke City Centre       14
# 14878        NaN      146                      Malvern East      132
#
#                           NEIGHBOURHOOD_140 DIVISION  ObjectId  ACC_NUM
# 659    Cabbagetown-South St.James Town (71)      D51       660      NaN
# 880                     South Parkdale (85)      D11       881      NaN
# 1141                            Rouge (131)      D42      1142      NaN
# 2558                    South Parkdale (85)      D14      2559      NaN
# 2916              Downsview-Roding-CFB (26)      D31      2917      NaN
# 3903               Rosedale-Moore Park (98)      D53      3904      NaN
# 3990              Downsview-Roding-CFB (26)      D31      3991      NaN
# 7524                Don Valley Village (47)      D33      7525      NaN
# 8694                   North Riverdale (68)      D55      8695      NaN
# 9470                    South Parkdale (85)      D14      9471      NaN
# 10355                   South Parkdale (85)      D11     10356      NaN
# 10380                   Kingsway South (15)      D22     10381      NaN
# 10919                  North Riverdale (68)      D55     10920      NaN
# 11097  Willowridge-Martingrove-Richview (7)      D23     11098      NaN
# 11303                  North Riverdale (68)      D55     11304      NaN
# 11478              Stonegate-Queensway (16)      D22     11479      NaN
# 11501                   South Parkdale (85)      D14     11502      NaN
# 11562                  Elms-Old Rexdale (5)      D23     11563      NaN
# 11572                     Morningside (135)      D43     11573      NaN
# 11918                    Old East York (58)      D55     11919      NaN
# 11944                          Niagara (82)      D14     11945      NaN
# 12291               Forest Hill South (101)      D13     12292      NaN
# 12530                      New Toronto (18)      D22     12531      NaN
# 12578                      Long Branch (19)      D22     12579      NaN
# 12807                    Humber Summit (21)      D31     12808      NaN
# 12913        Keelesdale-Eglinton West (110)      D12     12914      NaN
# 13614                  South Riverdale (70)      NSA     13615      NaN
# 13655             Clairlea-Birchmount (120)      D41     13656      NaN
# 13667                   South Parkdale (85)      D14     13668      NaN
# 13691                Wexford/Maryvale (119)      D41     13692      NaN
# 13776                      Cliffcrest (123)      D41     13777      NaN
# 13813                      Long Branch (19)      D22     13814      NaN
# 13871                   South Parkdale (85)      D14     13872      NaN
# 14347                       Guildwood (140)      D43     14348      NaN
# 14385               Leaside-Bennington (56)      D53     14386      NaN
# 14562            Bayview Woods-Steeles (49)      D33     14563      NaN
# 14588                  Willowdale East (51)      D32     14589      NaN
# 14623       Islington-City Centre West (14)      D22     14624      NaN
# 14878                         Malvern (132)      D42     14879      NaN

# %%
df[(df["ACC_NUM"].isna()) & (df["ACCLASS"] == "Non-Fatal Injury")]
# Out:
#              ACCNUM  YEAR                    DATE  TIME               STREET1  \
# 277    8.907670e+05  2006  2006/02/28 05:00:00+00  1754           RENFORTH DR
# 403    9.102580e+05  2006  2006/06/08 04:00:00+00  2340             KING ST E
# 515    9.054570e+05  2006  2006/05/26 04:00:00+00  2214           BATHURST ST
# 725    9.065260e+05  2006  2006/06/04 04:00:00+00  1655            BRIMLEY RD
# 773    9.151010e+05  2006  2006/07/24 04:00:00+00  1302     LAKE SHORE BLVD W
# ...             ...   ...                     ...   ...                   ...
# 11451  4.002973e+09  2014  2014/09/24 04:00:00+00  1130            BANBURY RD
# 11453  4.002973e+09  2014  2014/09/24 04:00:00+00  1151     551 THE WEST MALL
# 11497  4.003003e+09  2014  2014/09/28 04:00:00+00  1820  WILLIAM R ALLEN RD N
# 11667  4.003063e+09  2014  2014/10/08 04:00:00+00  2348    2835 ISLINGTON AVE
# 14288  1.780571e+08  2017  2017/11/22 05:00:00+00  1110           BAYVIEW AVE
#
#                       STREET2          OFFSET      ROAD_CLASS  \
# 277            EGLINTON AVE W             NaN  Major Arterial
# 403            ST LAWRENCE ST             NaN  Major Arterial
# 515              DAVENPORT RD             NaN  Major Arterial
# 725          CHARTLAND BLVD S             NaN  Major Arterial
# 773    JAMESON LAKESHORE RAMP             NaN  Major Arterial
# ...                       ...             ...             ...
# 11451          LAWRENCE AVE E   10 m North of       Collector
# 11453                     NaN             NaN  Minor Arterial
# 11497               RANEE AVE  100 m North of             NaN
# 11667                     NaN   25 m South of  Major Arterial
# 14288          LAWRENCE AVE E             NaN  Major Arterial
#
#                     DISTRICT  WARDNUM   LATITUDE  LONGITUDE      LOCCOORD  \
# 277           Etobicoke York        2  43.666645 -79.587390     Mid-Block
# 403    Toronto and East York       13  43.656145 -79.357490     Mid-Block
# 515    Toronto and East York       12  43.676745 -79.415790  Intersection
# 725              Scarborough       23  43.804745 -79.276690     Mid-Block
# 773    Toronto and East York        4  43.631745 -79.432590     Mid-Block
# ...                      ...      ...        ...        ...           ...
# 11451             North York       15  43.735106 -79.357433  Intersection
# 11453         Etobicoke York        2  43.651831 -79.570003     Mid-Block
# 11497             North York        8  43.724257 -79.447131     Mid-Block
# 11667         Etobicoke York        7  43.749804 -79.567989     Mid-Block
# 14288             North York       15  43.730132 -79.381397     Mid-Block
#
#                       ACCLOC        TRAFFCTL VISIBILITY             LIGHT  \
# 277                      NaN      No Control      Clear              Dark
# 403                      NaN      No Control       Rain              Dark
# 515          At Intersection  Traffic Signal      Clear              Dark
# 725          At Intersection      No Control      Clear          Daylight
# 773                      NaN      No Control      Clear          Daylight
# ...                      ...             ...        ...               ...
# 11451       Non Intersection      No Control      Clear          Daylight
# 11453       Non Intersection      No Control      Clear          Daylight
# 11497       Non Intersection      No Control      Clear          Daylight
# 11667  At/Near Private Drive      No Control      Clear  Dark, artificial
# 14288       Non Intersection      No Control      Clear          Daylight
#
#       RDSFCOND           ACCLASS           IMPACTYPE            INVTYPE  \
# 277        Dry  Non-Fatal Injury           SMV Other             Driver
# 403        Wet  Non-Fatal Injury           SMV Other  Motorcycle Driver
# 515        Dry  Non-Fatal Injury  Cyclist Collisions            Cyclist
# 725        Dry  Non-Fatal Injury           SMV Other             Driver
# 773        Dry  Non-Fatal Injury  Cyclist Collisions            Cyclist
# ...        ...               ...                 ...                ...
# 11451      Dry  Non-Fatal Injury           SMV Other             Driver
# 11453      Dry  Non-Fatal Injury           SMV Other             Driver
# 11497      Dry  Non-Fatal Injury           SMV Other  Motorcycle Driver
# 11667      Wet  Non-Fatal Injury           SMV Other             Driver
# 14288      Dry  Non-Fatal Injury           SMV Other             Driver
#
#          INVAGE INJURY  FATAL_NO INITDIR                    VEHTYPE  \
# 277    55 to 59  Major       NaN   North  Automobile, Station Wagon
# 403    50 to 54  Major       NaN    East                 Motorcycle
# 515    40 to 44  Major       NaN   South                    Bicycle
# 725    45 to 49  Major       NaN   South  Automobile, Station Wagon
# 773    30 to 34  Major       NaN    East                    Bicycle
# ...         ...    ...       ...     ...                        ...
# 11451  65 to 69  Major       NaN   South  Automobile, Station Wagon
# 11453  75 to 79  Major       NaN   North  Automobile, Station Wagon
# 11497  45 to 49  Major       NaN   North                 Motorcycle
# 11667  50 to 54  Major       NaN   North  Automobile, Station Wagon
# 14288  30 to 34  Major       NaN   South  Automobile, Station Wagon
#
#                  MANOEUVER                       DRIVACT  \
# 277            Going Ahead                         Other
# 403         Changing Lanes              Driving Properly
# 515            Going Ahead                           NaN
# 725    Slowing or Stopping                  Lost control
# 773            Going Ahead                           NaN
# ...                    ...                           ...
# 11451          Going Ahead                  Lost control
# 11453          Going Ahead                  Lost control
# 11497              Unknown                  Lost control
# 11667          Going Ahead  Speed too Fast For Condition
# 14288          Going Ahead              Driving Properly
#
#                                  DRIVCOND PEDTYPE PEDACT PEDCOND  \
# 277                               Unknown     NaN    NaN     NaN
# 403                                Normal     NaN    NaN     NaN
# 515                                   NaN     NaN    NaN     NaN
# 725        Medical or Physical Disability     NaN    NaN     NaN
# 773                                   NaN     NaN    NaN     NaN
# ...                                   ...     ...    ...     ...
# 11451      Medical or Physical Disability     NaN    NaN     NaN
# 11453                             Unknown     NaN    NaN     NaN
# 11497                             Unknown     NaN    NaN     NaN
# 11667  Ability Impaired, Alcohol Over .08     NaN    NaN     NaN
# 14288                              Normal     NaN    NaN     NaN
#
#                                               CYCLISTYPE        CYCACT  \
# 277                                                  NaN           NaN
# 403                                                  NaN           NaN
# 515    Cyclist loses control and strikes object (pole...  Lost control
# 725                                                  NaN           NaN
# 773    Cyclist loses control and strikes object (pole...  Lost control
# ...                                                  ...           ...
# 11451                                                NaN           NaN
# 11453                                                NaN           NaN
# 11497                                                NaN           NaN
# 11667                                                NaN           NaN
# 14288                                                NaN           NaN
#
#                  CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK  \
# 277                  NaN        NaN     NaN        Yes        NaN   NaN
# 403                  NaN        NaN     NaN        NaN        Yes   NaN
# 515    Had Been Drinking        NaN     Yes        NaN        NaN   NaN
# 725                  NaN        NaN     NaN        Yes        NaN   NaN
# 773              Unknown        NaN     Yes        NaN        NaN   NaN
# ...                  ...        ...     ...        ...        ...   ...
# 11451                NaN        NaN     NaN        Yes        NaN   NaN
# 11453                NaN        NaN     NaN        Yes        NaN   NaN
# 11497                NaN        NaN     NaN        NaN        Yes   NaN
# 11667                NaN        NaN     NaN        Yes        NaN   NaN
# 14288                NaN        NaN     NaN        Yes        NaN   NaN
#
#       TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL  \
# 277             NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 403             NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 515             NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 725             NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 773             NaN       NaN       NaN      NaN     NaN      NaN     NaN
# ...             ...       ...       ...      ...     ...      ...     ...
# 11451           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 11453           NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 11497           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 11667           NaN       NaN       NaN      Yes     Yes      NaN     Yes
# 14288           NaN       NaN       NaN      NaN     NaN      NaN     NaN
#
#       DISABILITY HOOD_158                  NEIGHBOURHOOD_158 HOOD_140  \
# 277          NaN       11     Eringate-Centennial-West Deane       11
# 403          NaN       73                          Moss Park       73
# 515          NaN       96                          Casa Loma       96
# 725          Yes      129                    Agincourt North      129
# 773          NaN       85                     South Parkdale       85
# ...          ...      ...                                ...      ...
# 11451        Yes       42                  Banbury-Don Mills       42
# 11453        NaN       13                Etobicoke West Mall       13
# 11497        NaN       32                Englemount-Lawrence       32
# 11667        NaN       21                      Humber Summit       21
# 14288        NaN       41  Bridle Path-Sunnybrook-York Mills       41
#
#                             NEIGHBOURHOOD_140 DIVISION  ObjectId  ACC_NUM
# 277       Eringate-Centennial-West Deane (11)      D22       278      NaN
# 403                            Moss Park (73)      D51       404      NaN
# 515                            Casa Loma (96)      D13       516      NaN
# 725                     Agincourt North (129)      D42       726      NaN
# 773                       South Parkdale (85)      D14       774      NaN
# ...                                       ...      ...       ...      ...
# 11451                  Banbury-Don Mills (42)      D33     11452      NaN
# 11453                Etobicoke West Mall (13)      D22     11454      NaN
# 11497                Englemount-Lawrence (32)      D32     11498      NaN
# 11667                      Humber Summit (21)      D31     11668      NaN
# 14288  Bridle Path-Sunnybrook-York Mills (41)      D53     14289      NaN
#
# [126 rows x 55 columns]

# %%
# Dropping rows where ACC_NUM is null and ACCLASS is Non-Fatal

to_drop2 = df[(df["ACC_NUM"].isna()) & (df["ACCLASS"] == "Non-Fatal Injury")].index

df = df.drop(to_drop2, axis=0)

# %%
df.ACC_NUM.max()
# Out:
# 3898.0

# %%
# Giving a new unique number in the continuetion of previously given numbers, for the records which did not match the requirements before

# %%
# Find null values in the 'ACC_NUM' column
null_values_indices = df[df['ACC_NUM'].isnull()].index

# Generate a sequence starting from 4545
sequence = range(3899, 3899 + len(null_values_indices))

# Fill null values with the generated sequence
df.loc[null_values_indices, 'ACC_NUM'] = sequence

# Display the DataFrame with filled null values
df["ACC_NUM"].isna().sum()
# Out:
# 0

# %%
df[df.ACC_NUM.isna()]
# Out:
# Empty DataFrame
# Columns: [ACCNUM, YEAR, DATE, TIME, STREET1, STREET2, OFFSET, ROAD_CLASS, DISTRICT, WARDNUM, LATITUDE, LONGITUDE, LOCCOORD, ACCLOC, TRAFFCTL, VISIBILITY, LIGHT, RDSFCOND, ACCLASS, IMPACTYPE, INVTYPE, INVAGE, INJURY, FATAL_NO, INITDIR, VEHTYPE, MANOEUVER, DRIVACT, DRIVCOND, PEDTYPE, PEDACT, PEDCOND, CYCLISTYPE, CYCACT, CYCCOND, PEDESTRIAN, CYCLIST, AUTOMOBILE, MOTORCYCLE, TRUCK, TRSN_CITY_VEH, EMERG_VEH, PASSENGER, SPEEDING, AG_DRIV, REDLIGHT, ALCOHOL, DISABILITY, HOOD_158, NEIGHBOURHOOD_158, HOOD_140, NEIGHBOURHOOD_140, DIVISION, ObjectId, ACC_NUM]
# Index: []

# %%
df.ACC_NUM.max()
# Out:
# 3937.0

# %%
# We can remove the ACCNUM column now

# %%
df.drop('ACCNUM', axis=1, inplace=True)

# %%
# Checking ACCLASS's number of FATAL values, whether the values of is same or not

# %%
df["ACCLASS"].value_counts()
# Out:
# Non-Fatal Injury    9755
# Fatal               2022
# Name: ACCLASS, dtype: int64

# %% [markdown]
# # #YEAR

# %%
# Removing YEAR column as it is not relevant

# %%
df.drop("YEAR", axis=1, inplace=True)

# %% [markdown]
# # #DATE

# %%
# Removig DATE column as it is not relevant

# %%
df.drop("DATE", axis=1, inplace=True)

# %% [markdown]
# # #TIME

# %%
# Keeping time column because it may affect the accident class

# %%
df.sample(5)
# Out:
#       TIME       STREET1           STREET2 OFFSET      ROAD_CLASS  \
# 5048  1605    HORNER AVE         EDILOU DR    NaN  Minor Arterial
# 2597  1921  DANFORTH AVE  MONARCH PARK AVE    NaN  Major Arterial
# 216    856      PAPE AVE       CANNING AVE    NaN  Major Arterial
# 9196  1529    WARDEN AVE          HYMUS RD    NaN  Major Arterial
# 4446  1444   DUNDAS ST W      SORAUREN AVE    NaN  Minor Arterial
#
#                    DISTRICT  WARDNUM   LATITUDE  LONGITUDE      LOCCOORD  \
# 5048         Etobicoke York        3  43.604745  -79.53139  Intersection
# 2597  Toronto and East York       14  43.682545  -79.32719  Intersection
# 216   Toronto and East York       14  43.682345  -79.34609  Intersection
# 9196            Scarborough       20  43.719545  -79.28419  Intersection
# 4446  Toronto and East York        4  43.651145  -79.44529  Intersection
#
#      ACCLOC        TRAFFCTL VISIBILITY     LIGHT RDSFCOND           ACCLASS  \
# 5048    NaN      No Control      Clear  Daylight      Dry             Fatal
# 2597    NaN  Traffic Signal       Rain      Dark      Wet  Non-Fatal Injury
# 216     NaN      No Control      Clear  Daylight      Dry  Non-Fatal Injury
# 9196    NaN      No Control      Clear  Daylight      Dry  Non-Fatal Injury
# 4446    NaN      No Control      Clear  Daylight      Dry  Non-Fatal Injury
#
#                   IMPACTYPE       INVTYPE    INVAGE INJURY  FATAL_NO INITDIR  \
# 5048  Pedestrian Collisions  Truck Driver  45 to 49   None       NaN    West
# 2597  Pedestrian Collisions    Pedestrian  35 to 39  Major       NaN   South
# 216                Rear End        Driver  50 to 54  Major       NaN   South
# 9196            Approaching     Passenger  50 to 54  Minor       NaN     NaN
# 4446     Cyclist Collisions       Cyclist  30 to 34  Major       NaN    West
#
#                         VEHTYPE    MANOEUVER              DRIVACT DRIVCOND  \
# 5048               Truck - Open  Going Ahead     Driving Properly   Normal
# 2597                      Other          NaN                  NaN      NaN
# 216   Automobile, Station Wagon  Going Ahead  Following too Close  Fatigue
# 9196                      Other          NaN                  NaN      NaN
# 4446                    Bicycle  Going Ahead                  NaN      NaN
#
#                                                 PEDTYPE                PEDACT  \
# 5048                                                NaN                   NaN
# 2597  Vehicle is going straight thru inter.while ped...  Running onto Roadway
# 216                                                 NaN                   NaN
# 9196                                                NaN                   NaN
# 4446                                                NaN                   NaN
#
#      PEDCOND                                         CYCLISTYPE  \
# 5048     NaN                                                NaN
# 2597  Normal                                                NaN
# 216      NaN                                                NaN
# 9196     NaN                                                NaN
# 4446     NaN  Cyclist and Driver travelling in same directio...
#
#                 CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK  \
# 5048               NaN     NaN        Yes     NaN        NaN        NaN   Yes
# 2597               NaN     NaN        Yes     NaN        Yes        NaN   NaN
# 216                NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 9196               NaN     NaN        NaN     NaN        Yes        NaN   NaN
# 4446  Driving Properly  Normal        NaN     Yes        Yes        NaN   NaN
#
#      TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL  \
# 5048           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 2597           NaN       NaN       NaN      NaN     NaN      NaN     NaN
# 216            NaN       NaN       NaN      Yes     Yes      NaN     NaN
# 9196           NaN       NaN       Yes      NaN     Yes      NaN     NaN
# 4446           NaN       NaN       NaN      NaN     Yes      NaN     NaN
#
#      DISABILITY HOOD_158    NEIGHBOURHOOD_158 HOOD_140  \
# 5048        NaN       20            Alderwood       20
# 2597        NaN       65    Greenwood-Coxwell       65
# 216         NaN       66             Danforth       66
# 9196        NaN      120  Clairlea-Birchmount      120
# 4446        NaN       86         Roncesvalles       86
#
#               NEIGHBOURHOOD_140 DIVISION  ObjectId  ACC_NUM
# 5048             Alderwood (20)      D22      5049   1781.0
# 2597     Greenwood-Coxwell (65)      D55      2598    628.0
# 216               Danforth (66)      D55       217     36.0
# 9196  Clairlea-Birchmount (120)      D41      9197   2952.0
# 4446          Roncesvalles (86)      D11      4447   1379.0

# %%
# We can divide time in parts of the day

# %%
# Function to map time values to segments of the day
def map_time_to_segment(time):
    if time < 600:
        return 'Midnight'
    elif time < 1200:
        return 'Morning'
    elif time < 1700:
        return 'Afternoon'
    elif time < 2100:
        return 'Evening'
    else:
        return 'Night'

# Apply the function to create a new column 'TIME_SEGMENT'
df['TIME_SEGMENT'] = df['TIME'].apply(map_time_to_segment)

# %%
df[['TIME','TIME_SEGMENT']]
# Out:
#        TIME TIME_SEGMENT
# 0       852      Morning
# 1       852      Morning
# 2       915      Morning
# 3       236     Midnight
# 4       915      Morning
# ...     ...          ...
# 14960  1903      Evening
# 14964  1903      Evening
# 14967  1903      Evening
# 14980   709      Morning
# 14981   709      Morning
#
# [11777 rows x 2 columns]

# %%
# we can drop the TIME column

# %%
df.drop('TIME', axis=1, inplace=True)

# %% [markdown]
# # #STREET1

# %%
# Keeping STREET1 as it is
df.STREET1.isna().sum()
# Out:
# 0

# %% [markdown]
# # #STREET2

# %%
# Filling null values in STREET2 with Not Applicabel(N/A)

# %%
df['STREET2'].fillna('NA', inplace=True)

# %%
df.STREET2.isna().sum()
# Out:
# 0

# %% [markdown]
# # #ROAD_CLASS

# %%
df.ROAD_CLASS.value_counts()
# Out:
# Major Arterial    8423
# Minor Arterial    1785
# Collector          672
# Local              554
# Other               25
# Expressway           8
# Laneway              6
# Pending              2
# Name: ROAD_CLASS, dtype: int64

# %%
df['ROAD_CLASS'].fillna('Major Arterial', inplace=True)

# %%
df.ROAD_CLASS.isna().sum()
# Out:
# 0

# %%
#  Now we can drop those ACCNUM column because we have our own ACC_NUM which has no null values

# %%
df.columns
# Out:
# Index(['STREET1', 'STREET2', 'OFFSET', 'ROAD_CLASS', 'DISTRICT', 'WARDNUM',
#        'LATITUDE', 'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY',
#        'LIGHT', 'RDSFCOND', 'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE',
#        'INJURY', 'FATAL_NO', 'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT',
#        'DRIVCOND', 'PEDTYPE', 'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT',
#        'CYCCOND', 'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK',
#        'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV',
#        'REDLIGHT', 'ALCOHOL', 'DISABILITY', 'HOOD_158', 'NEIGHBOURHOOD_158',
#        'HOOD_140', 'NEIGHBOURHOOD_140', 'DIVISION', 'ObjectId', 'ACC_NUM',
#        'TIME_SEGMENT'],
#       dtype='object')

# %% [markdown]
# # #OFFSET

# %%
df.OFFSET.isna().sum()
# Out:
# 11438

# %%
# OFFSET has large number of missing values therefore removing it

# %%
df.drop("OFFSET", axis=1, inplace=True)

# %% [markdown]
# # #ROAD_CLASS

# %%
# Displaying Roadclass column values and if it's class i non-fatal then removing those clumns

# %%
df[(df['ROAD_CLASS'].isna())&(df['ACCLASS'] == "Fatal")]
# Out:
# Empty DataFrame
# Columns: [STREET1, STREET2, ROAD_CLASS, DISTRICT, WARDNUM, LATITUDE, LONGITUDE, LOCCOORD, ACCLOC, TRAFFCTL, VISIBILITY, LIGHT, RDSFCOND, ACCLASS, IMPACTYPE, INVTYPE, INVAGE, INJURY, FATAL_NO, INITDIR, VEHTYPE, MANOEUVER, DRIVACT, DRIVCOND, PEDTYPE, PEDACT, PEDCOND, CYCLISTYPE, CYCACT, CYCCOND, PEDESTRIAN, CYCLIST, AUTOMOBILE, MOTORCYCLE, TRUCK, TRSN_CITY_VEH, EMERG_VEH, PASSENGER, SPEEDING, AG_DRIV, REDLIGHT, ALCOHOL, DISABILITY, HOOD_158, NEIGHBOURHOOD_158, HOOD_140, NEIGHBOURHOOD_140, DIVISION, ObjectId, ACC_NUM, TIME_SEGMENT]
# Index: []

# %%
# There are record where ROAD_CLASS is null and it' ACCLASS is null, for that reason we are imputing road class values with most accured values from that column.

# %%
# we dont have any null values in road class where acclass is FATAL, it means we can remove all null records

# %%
df = df.dropna(subset=['ROAD_CLASS'])

# %%
df.ROAD_CLASS.isna().sum()
# Out:
# 0

# %% [markdown]
# #  #DISTRICT

# %%
# Checking null values of DISCTRICT if they are not of FATAL ACCLASS then removing it

# %%
df[(df['DISTRICT'].isna())&(df['ACCLASS'] == "Non-Fatal Injury")]
# Out:
#                   STREET1         STREET2      ROAD_CLASS DISTRICT  WARDNUM  \
# 11915  WILLIAM R ALLEN RD  SHEPPARD AVE W  Major Arterial      NaN        6
# 11917  WILLIAM R ALLEN RD  SHEPPARD AVE W  Major Arterial      NaN        6
#
#         LATITUDE  LONGITUDE   LOCCOORD                 ACCLOC    TRAFFCTL  \
# 11915  43.748622 -79.462856  Mid-Block  At/Near Private Drive  No Control
# 11917  43.748622 -79.462856  Mid-Block  At/Near Private Drive  No Control
#
#       VISIBILITY             LIGHT RDSFCOND           ACCLASS  \
# 11915      Clear  Dark, artificial      Dry  Non-Fatal Injury
# 11917      Clear  Dark, artificial      Dry  Non-Fatal Injury
#
#               IMPACTYPE       INVTYPE    INVAGE INJURY  FATAL_NO INITDIR  \
# 11915  Turning Movement  Truck Driver  25 to 29   None       NaN    East
# 11917  Turning Movement     Passenger  30 to 34  Major       NaN     NaN
#
#              VEHTYPE      MANOEUVER                       DRIVACT  \
# 11915  Truck-Tractor  Turning Right  Failed to Yield Right of Way
# 11917            NaN            NaN                           NaN
#
#           DRIVCOND PEDTYPE PEDACT PEDCOND CYCLISTYPE CYCACT CYCCOND  \
# 11915  Inattentive     NaN    NaN     NaN        NaN    NaN     NaN
# 11917          NaN     NaN    NaN     NaN        NaN    NaN     NaN
#
#       PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 11915        NaN     NaN        NaN        NaN   Yes           NaN       NaN
# 11917        NaN     NaN        NaN        NaN   Yes           NaN       NaN
#
#       PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158  \
# 11915       Yes      NaN     Yes      NaN     NaN        NaN      155
# 11917       Yes      NaN     Yes      NaN     NaN        NaN      155
#
#       NEIGHBOURHOOD_158 HOOD_140          NEIGHBOURHOOD_140 DIVISION  \
# 11915         Downsview       26  Downsview-Roding-CFB (26)      D32
# 11917         Downsview       26  Downsview-Roding-CFB (26)      D32
#
#        ObjectId  ACC_NUM TIME_SEGMENT
# 11915     11916   3625.0     Midnight
# 11917     11918   3625.0     Midnight

# %%
# drop_district = df[(df['DISTRICT'].isna()) & (df['ACCLASS'] == "Non-Fatal Injury")].index


drop_district = df[(df["DISTRICT"].isna()) & (df["ACCLASS"] == "Non-Fatal Injury")].index

df = df.drop(drop_district, axis=0)

# %%
df['DISTRICT']
# Out:
# 0        Toronto and East York
# 1        Toronto and East York
# 2                  Scarborough
# 3        Toronto and East York
# 4                  Scarborough
#                  ...
# 14960               North York
# 14964               North York
# 14967               North York
# 14980              Scarborough
# 14981              Scarborough
# Name: DISTRICT, Length: 11775, dtype: object

# %% [markdown]
# # #LOCCOORD

# %%
# Checking null values of LOCCOORD if they are not of FATAL ACCLASS then removing it

# %%
df[(df['LOCCOORD'].isna())&(df['ACCLASS'] == "Fatal")]
# Out:
# Empty DataFrame
# Columns: [STREET1, STREET2, ROAD_CLASS, DISTRICT, WARDNUM, LATITUDE, LONGITUDE, LOCCOORD, ACCLOC, TRAFFCTL, VISIBILITY, LIGHT, RDSFCOND, ACCLASS, IMPACTYPE, INVTYPE, INVAGE, INJURY, FATAL_NO, INITDIR, VEHTYPE, MANOEUVER, DRIVACT, DRIVCOND, PEDTYPE, PEDACT, PEDCOND, CYCLISTYPE, CYCACT, CYCCOND, PEDESTRIAN, CYCLIST, AUTOMOBILE, MOTORCYCLE, TRUCK, TRSN_CITY_VEH, EMERG_VEH, PASSENGER, SPEEDING, AG_DRIV, REDLIGHT, ALCOHOL, DISABILITY, HOOD_158, NEIGHBOURHOOD_158, HOOD_140, NEIGHBOURHOOD_140, DIVISION, ObjectId, ACC_NUM, TIME_SEGMENT]
# Index: []

# %%
df[(df['LOCCOORD'].isna())&(df['ACCLASS'] == "Non-Fatal Injury")]
# Out:
#                       STREET1                   STREET2      ROAD_CLASS  \
# 278               DANFORTH RD            EGLINTON AVE E  Major Arterial
# 279               DANFORTH RD            EGLINTON AVE E  Major Arterial
# 280               DANFORTH RD            EGLINTON AVE E  Major Arterial
# 281               DANFORTH RD            EGLINTON AVE E  Major Arterial
# 1049              DUFFERIN ST           GLEN BELLE CRES  Major Arterial
# ...                       ...                       ...             ...
# 9869        LAKE SHORE BLVD W                QUEENS AVE  Major Arterial
# 9871        LAKE SHORE BLVD W                QUEENS AVE  Major Arterial
# 9882        LAKE SHORE BLVD W                QUEENS AVE  Major Arterial
# 10963  BAYVIEW BLOOR DVP RAMP  BAYVIEW BLOOR DVP N RAMP  Major Arterial
# 10976  BAYVIEW BLOOR DVP RAMP  BAYVIEW BLOOR DVP N RAMP  Major Arterial
#
#                     DISTRICT  WARDNUM   LATITUDE  LONGITUDE LOCCOORD ACCLOC  \
# 278              Scarborough     2120  43.737045  -79.24619      NaN    NaN
# 279              Scarborough     2120  43.737045  -79.24619      NaN    NaN
# 280              Scarborough     2120  43.737045  -79.24619      NaN    NaN
# 281              Scarborough     2120  43.737045  -79.24619      NaN    NaN
# 1049              North York        8  43.722245  -79.45649      NaN    NaN
# ...                      ...      ...        ...        ...      ...    ...
# 9869          Etobicoke York        3  43.609660  -79.49026      NaN    NaN
# 9871          Etobicoke York        3  43.609660  -79.49026      NaN    NaN
# 9882          Etobicoke York        3  43.609660  -79.49026      NaN    NaN
# 10963  Toronto and East York       14  43.683283  -79.36021      NaN    NaN
# 10976  Toronto and East York       14  43.683283  -79.36021      NaN    NaN
#
#              TRAFFCTL VISIBILITY     LIGHT RDSFCOND           ACCLASS  \
# 278    Traffic Signal      Clear      Dark      Dry  Non-Fatal Injury
# 279    Traffic Signal      Clear      Dark      Dry  Non-Fatal Injury
# 280    Traffic Signal      Clear      Dark      Dry  Non-Fatal Injury
# 281    Traffic Signal      Clear      Dark      Dry  Non-Fatal Injury
# 1049       No Control      Clear      Dark      Wet  Non-Fatal Injury
# ...               ...        ...       ...      ...               ...
# 9869       No Control      Clear  Daylight      Dry  Non-Fatal Injury
# 9871       No Control      Clear  Daylight      Dry  Non-Fatal Injury
# 9882       No Control      Clear  Daylight      Dry  Non-Fatal Injury
# 10963      Yield Sign      Clear      Dark      Dry  Non-Fatal Injury
# 10976      Yield Sign      Clear      Dark      Dry  Non-Fatal Injury
#
#                    IMPACTYPE        INVTYPE    INVAGE INJURY  FATAL_NO  \
# 278    Pedestrian Collisions  Vehicle Owner   unknown   None       NaN
# 279    Pedestrian Collisions         Driver   unknown   None       NaN
# 280    Pedestrian Collisions     Pedestrian   unknown  Minor       NaN
# 281    Pedestrian Collisions     Pedestrian   unknown  Major       NaN
# 1049   Pedestrian Collisions         Driver   unknown   None       NaN
# ...                      ...            ...       ...    ...       ...
# 9869        Turning Movement         Driver  50 to 54  Major       NaN
# 9871        Turning Movement  Vehicle Owner   unknown    NaN       NaN
# 9882        Turning Movement         Driver  20 to 24  Minor       NaN
# 10963              SMV Other      Passenger   unknown  Minor       NaN
# 10976              SMV Other         Driver  30 to 34  Major       NaN
#
#       INITDIR                    VEHTYPE      MANOEUVER DRIVACT  \
# 278       NaN                      Other        Unknown     NaN
# 279      West  Automobile, Station Wagon    Going Ahead     NaN
# 280       NaN                      Other          Other     NaN
# 281       NaN                      Other          Other     NaN
# 1049      NaN  Automobile, Station Wagon        Unknown     NaN
# ...       ...                        ...            ...     ...
# 9869      NaN  Automobile, Station Wagon    Going Ahead     NaN
# 9871      NaN                      Other            NaN     NaN
# 9882      NaN  Automobile, Station Wagon  Making U Turn     NaN
# 10963     NaN                      Other            NaN     NaN
# 10976   North  Automobile, Station Wagon        Merging     NaN
#
#                         DRIVCOND  PEDTYPE PEDACT PEDCOND CYCLISTYPE CYCACT  \
# 278                          NaN      NaN    NaN     NaN        NaN    NaN
# 279                          NaN      NaN    NaN     NaN        NaN    NaN
# 280                          NaN  Unknown    NaN     NaN        NaN    NaN
# 281                          NaN  Unknown    NaN     NaN        NaN    NaN
# 1049                         NaN      NaN    NaN     NaN        NaN    NaN
# ...                          ...      ...    ...     ...        ...    ...
# 9869                         NaN      NaN    NaN     NaN        NaN    NaN
# 9871                         NaN      NaN    NaN     NaN        NaN    NaN
# 9882                         NaN      NaN    NaN     NaN        NaN    NaN
# 10963                        NaN      NaN    NaN     NaN        NaN    NaN
# 10976  Ability Impaired, Alcohol      NaN    NaN     NaN        NaN    NaN
#
#       CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH  \
# 278       NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 279       NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 280       NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 281       NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 1049      NaN        Yes     NaN        Yes        NaN   NaN           NaN
# ...       ...        ...     ...        ...        ...   ...           ...
# 9869      NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 9871      NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 9882      NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 10963     NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 10976     NaN        NaN     NaN        Yes        NaN   NaN           NaN
#
#       EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY  \
# 278         NaN       NaN      NaN     NaN      NaN     NaN        NaN
# 279         NaN       NaN      NaN     NaN      NaN     NaN        NaN
# 280         NaN       NaN      NaN     NaN      NaN     NaN        NaN
# 281         NaN       NaN      NaN     NaN      NaN     NaN        NaN
# 1049        NaN       NaN      NaN     NaN      NaN     NaN        NaN
# ...         ...       ...      ...     ...      ...     ...        ...
# 9869        NaN       Yes      NaN     NaN      NaN     NaN        NaN
# 9871        NaN       Yes      NaN     NaN      NaN     NaN        NaN
# 9882        NaN       Yes      NaN     NaN      NaN     NaN        NaN
# 10963       NaN       Yes      NaN     NaN      NaN     Yes        NaN
# 10976       NaN       Yes      NaN     NaN      NaN     Yes        NaN
#
#       HOOD_158   NEIGHBOURHOOD_158 HOOD_140  \
# 278        138       Eglinton East      138
# 279        138       Eglinton East      138
# 280        138       Eglinton East      138
# 281        138       Eglinton East      138
# 1049        31  Yorkdale-Glen Park       31
# ...        ...                 ...      ...
# 9869       160    Mimico-Queensway       17
# 9871       160    Mimico-Queensway       17
# 9882       160    Mimico-Queensway       17
# 10963       57     Broadview North       57
# 10976       57     Broadview North       57
#
#                               NEIGHBOURHOOD_140 DIVISION  ObjectId  ACC_NUM  \
# 278                         Eglinton East (138)      D43       279     55.0
# 279                         Eglinton East (138)      D43       280     55.0
# 280                         Eglinton East (138)      D43       281     55.0
# 281                         Eglinton East (138)      D43       282     55.0
# 1049                    Yorkdale-Glen Park (31)      D32      1050    417.0
# ...                                         ...      ...       ...      ...
# 9869   Mimico (includes Humber Bay Shores) (17)      D22      9870   3175.0
# 9871   Mimico (includes Humber Bay Shores) (17)      D22      9872   3175.0
# 9882   Mimico (includes Humber Bay Shores) (17)      D22      9883   3175.0
# 10963                      Broadview North (57)      D55     10964   3246.0
# 10976                      Broadview North (57)      D55     10977   3246.0
#
#       TIME_SEGMENT
# 278          Night
# 279          Night
# 280          Night
# 281          Night
# 1049       Morning
# ...            ...
# 9869     Afternoon
# 9871     Afternoon
# 9882     Afternoon
# 10963     Midnight
# 10976     Midnight
#
# [85 rows x 51 columns]

# %%
# There are null values in LOCCOORD whicha have ACCLASS as Non-Fatal, we can drop those colums

# %%
drop_loccoord = df[(df["LOCCOORD"].isna()) & (df["ACCLASS"] == "Non-Fatal Injury")].index

df = df.drop(drop_loccoord, axis=0)

# %% [markdown]
# # #ACCLOC

# %%
# Checking values of ACCLOC

# %%
df["ACCLOC"].value_counts()
# Out:
# At Intersection          5466
# Non Intersection          558
# Intersection Related      308
# At/Near Private Drive      47
# Underpass or Tunnel         5
# Private Driveway            5
# Overpass or Bridge          5
# Name: ACCLOC, dtype: int64

# %%
df[(df["ACCLOC"].isna()) & (df["ACCLASS"] == "Fatal")]
# Out:
#               STREET1           STREET2      ROAD_CLASS        DISTRICT  \
# 5      EGLINTON AVE E  COMMONWEALTH AVE  Major Arterial     Scarborough
# 8      EGLINTON AVE E  COMMONWEALTH AVE  Major Arterial     Scarborough
# 9      EGLINTON AVE E  COMMONWEALTH AVE  Major Arterial     Scarborough
# 166     STEELES AVE E     NINTH LINE ST  Minor Arterial     Scarborough
# 170     STEELES AVE E     NINTH LINE ST  Minor Arterial     Scarborough
# ...               ...               ...             ...             ...
# 12442   BIRMINGHAM ST   TWENTY FIRST ST       Collector  Etobicoke York
# 12449   BIRMINGHAM ST   TWENTY FIRST ST       Collector  Etobicoke York
# 12485    WEDGEWOOD DR       TOBRUK CRES           Local      North York
# 12493    WEDGEWOOD DR       TOBRUK CRES           Local      North York
# 12807   STEELES AVE W     ISLINGTON AVE  Major Arterial  Etobicoke York
#
#        WARDNUM   LATITUDE  LONGITUDE      LOCCOORD ACCLOC  \
# 5         2120  43.734945 -79.256190     Mid-Block    NaN
# 8         2120  43.734945 -79.256190     Mid-Block    NaN
# 9         2120  43.734945 -79.256190     Mid-Block    NaN
# 166         25  43.842745 -79.224790     Mid-Block    NaN
# 170         25  43.842745 -79.224790     Mid-Block    NaN
# ...        ...        ...        ...           ...    ...
# 12442        3  43.599963 -79.521175  Intersection    NaN
# 12449        3  43.599963 -79.521175  Intersection    NaN
# 12485       18  43.789603 -79.413997  Intersection    NaN
# 12493       18  43.789603 -79.413997  Intersection    NaN
# 12807        7  43.764662 -79.573322     Mid-Block    NaN
#
#                    TRAFFCTL VISIBILITY     LIGHT RDSFCOND ACCLASS  \
# 5                No Control      Clear      Dark      Dry   Fatal
# 8                No Control      Clear      Dark      Dry   Fatal
# 9                No Control      Clear      Dark      Dry   Fatal
# 166              No Control      Clear      Dark      Wet   Fatal
# 170              No Control      Clear      Dark      Wet   Fatal
# ...                     ...        ...       ...      ...     ...
# 12442  Pedestrian Crossover      Clear  Daylight      Dry   Fatal
# 12449  Pedestrian Crossover      Clear  Daylight      Dry   Fatal
# 12485             Stop Sign      Clear  Daylight      Wet   Fatal
# 12493             Stop Sign      Clear  Daylight      Wet   Fatal
# 12807            No Control      Clear  Daylight      Dry   Fatal
#
#                    IMPACTYPE            INVTYPE    INVAGE   INJURY  FATAL_NO  \
# 5      Pedestrian Collisions             Driver  25 to 29     None       NaN
# 8      Pedestrian Collisions         Pedestrian  30 to 34    Minor       NaN
# 9      Pedestrian Collisions         Pedestrian  40 to 44    Fatal       NaN
# 166              Approaching             Driver  50 to 54    Fatal       NaN
# 170              Approaching      Vehicle Owner   unknown      NaN       NaN
# ...                      ...                ...       ...      ...       ...
# 12442              Sideswipe             Driver  85 to 89    Fatal       9.0
# 12449              Sideswipe             Driver  30 to 34  Minimal       NaN
# 12485  Pedestrian Collisions             Driver  45 to 49  Minimal       NaN
# 12493  Pedestrian Collisions         Pedestrian  80 to 84    Fatal      12.0
# 12807               Rear End  Motorcycle Driver  25 to 29    Fatal      16.0
#
#       INITDIR                    VEHTYPE    MANOEUVER  \
# 5        West  Automobile, Station Wagon  Going Ahead
# 8       South                      Other          NaN
# 9       South                      Other          NaN
# 166      West  Automobile, Station Wagon  Going Ahead
# 170       NaN                      Other          NaN
# ...       ...                        ...          ...
# 12442    West  Automobile, Station Wagon  Going Ahead
# 12449    West  Automobile, Station Wagon  Going Ahead
# 12485    East  Automobile, Station Wagon  Going Ahead
# 12493    West                        NaN          NaN
# 12807    West                 Motorcycle  Going Ahead
#
#                             DRIVACT                   DRIVCOND  \
# 5                             Other  Ability Impaired, Alcohol
# 8                               NaN                        NaN
# 9                               NaN                        NaN
# 166                    Lost control                    Unknown
# 170                             NaN                        NaN
# ...                             ...                        ...
# 12442                  Lost control                    Unknown
# 12449              Driving Properly                     Normal
# 12485                  Lost control                Inattentive
# 12493                           NaN                        NaN
# 12807  Speed too Fast For Condition                    Unknown
#
#                                       PEDTYPE                        PEDACT  \
# 5                                         NaN                           NaN
# 8                 Pedestrian hit at mid-block  Crossing, no Traffic Control
# 9                 Pedestrian hit at mid-block  Crossing, no Traffic Control
# 166                                       NaN                           NaN
# 170                                       NaN                           NaN
# ...                                       ...                           ...
# 12442                                     NaN                           NaN
# 12449                                     NaN                           NaN
# 12485                                     NaN                           NaN
# 12493  Pedestrian hit on sidewalk or shoulder       On Sidewalk or Shoulder
# 12807                                     NaN                           NaN
#
#       PEDCOND CYCLISTYPE CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE  \
# 5         NaN        NaN    NaN     NaN        Yes     NaN        Yes
# 8      Normal        NaN    NaN     NaN        Yes     NaN        Yes
# 9      Normal        NaN    NaN     NaN        Yes     NaN        Yes
# 166       NaN        NaN    NaN     NaN        NaN     NaN        Yes
# 170       NaN        NaN    NaN     NaN        NaN     NaN        Yes
# ...       ...        ...    ...     ...        ...     ...        ...
# 12442     NaN        NaN    NaN     NaN        NaN     NaN        Yes
# 12449     NaN        NaN    NaN     NaN        NaN     NaN        Yes
# 12485     NaN        NaN    NaN     NaN        Yes     NaN        Yes
# 12493  Normal        NaN    NaN     NaN        Yes     NaN        Yes
# 12807     NaN        NaN    NaN     NaN        NaN     NaN        NaN
#
#       MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV  \
# 5            NaN   NaN           NaN       NaN       NaN      NaN     NaN
# 8            NaN   NaN           NaN       NaN       NaN      NaN     NaN
# 9            NaN   NaN           NaN       NaN       NaN      NaN     NaN
# 166          NaN   NaN           NaN       NaN       NaN      NaN     NaN
# 170          NaN   NaN           NaN       NaN       NaN      NaN     NaN
# ...          ...   ...           ...       ...       ...      ...     ...
# 12442        NaN   NaN           NaN       NaN       NaN      Yes     Yes
# 12449        NaN   NaN           NaN       NaN       NaN      Yes     Yes
# 12485        NaN   NaN           NaN       NaN       NaN      NaN     Yes
# 12493        NaN   NaN           NaN       NaN       NaN      NaN     Yes
# 12807        Yes   NaN           NaN       NaN       NaN      Yes     Yes
#
#       REDLIGHT ALCOHOL DISABILITY HOOD_158    NEIGHBOURHOOD_158 HOOD_140  \
# 5          NaN     Yes        NaN      124         Kennedy Park      138
# 8          NaN     Yes        NaN      124         Kennedy Park      138
# 9          NaN     Yes        NaN      124         Kennedy Park      138
# 166        NaN     NaN        NaN      144  Morningside Heights      131
# 170        NaN     NaN        NaN      144  Morningside Heights      131
# ...        ...     ...        ...      ...                  ...      ...
# 12442      NaN     NaN        NaN       18          New Toronto       18
# 12449      NaN     NaN        NaN       18          New Toronto       18
# 12485      NaN     NaN        NaN       50     Newtonbrook East       50
# 12493      NaN     NaN        NaN       50     Newtonbrook East       50
# 12807      NaN     NaN        NaN       21        Humber Summit       21
#
#            NEIGHBOURHOOD_140 DIVISION  ObjectId  ACC_NUM TIME_SEGMENT
# 5        Eglinton East (138)      D41         6     62.0     Midnight
# 8        Eglinton East (138)      D41         9     62.0     Midnight
# 9        Eglinton East (138)      D41        10     62.0     Midnight
# 166              Rouge (131)      D42       167      5.0        Night
# 170              Rouge (131)      D42       171      5.0        Night
# ...                      ...      ...       ...      ...          ...
# 12442       New Toronto (18)      D22     12443   3735.0      Morning
# 12449       New Toronto (18)      D22     12450   3735.0      Morning
# 12485  Newtonbrook East (50)      D32     12486   3736.0      Morning
# 12493  Newtonbrook East (50)      D32     12494   3736.0      Morning
# 12807     Humber Summit (21)      D31     12808   3923.0      Evening
#
# [795 rows x 51 columns]

# %%
# Removing ACCLOC column as it has large number of missing values

# %%
df = df.drop("ACCLOC", axis=1)

# %% [markdown]
# # #TRAFFCTL

# %%
# Checking values of TRAFFCTL

# %%
df.TRAFFCTL.value_counts()
# Out:
# No Control              5679
# Traffic Signal          4891
# Stop Sign                894
# Pedestrian Crossover     142
# Traffic Controller        45
# Yield Sign                 9
# Streetcar (Stop for)       9
# Traffic Gate               5
# School Guard               2
# Police Control             2
# Name: TRAFFCTL, dtype: int64

# %%
df.TRAFFCTL.isna().sum()
# Out:
# 12

# %%
# We can fill missing values with the most occured value

# %%
df['TRAFFCTL'].fillna('No Control', inplace=True)

# %%
df.TRAFFCTL.isna().sum()
# Out:
# 0

# %% [markdown]
# # #VISIBILITY

# %%
df.VISIBILITY.value_counts()
# Out:
# Clear                     9969
# Rain                      1304
# Snow                       251
# Other                       69
# Fog, Mist, Smoke, Dust      38
# Freezing Rain               27
# Drifting Snow               12
# Strong wind                  6
# Name: VISIBILITY, dtype: int64

# %%
# We can impute missing values in VISIBILTY

# %%
df['VISIBILITY'].fillna('Clear', inplace=True)

# %%
df.TRAFFCTL.isna().sum()
# Out:
# 0

# %% [markdown]
# # #RDFSCOND

# %%
# Checking values of RDFSCOND

# %%
df.RDSFCOND.value_counts()
# Out:
# Dry                     9225
# Wet                     2050
# Loose Snow               122
# Other                    109
# Slush                     76
# Ice                       51
# Packed Snow               35
# Loose Sand or Gravel       3
# Name: RDSFCOND, dtype: int64

# %%
df['RDSFCOND'].isna().sum()
# Out:
# 19

# %%
df['RDSFCOND'].fillna('Dry', inplace=True)

# %% [markdown]
# # #INVTYPE

# %%
# Checking values of INVTYPE

# %%
df.INVTYPE.value_counts()
# Out:
# Driver                  5127
# Pedestrian              1943
# Vehicle Owner           1620
# Passenger               1542
# Cyclist                  457
# Motorcycle Driver        314
# Other Property Owner     255
# Truck Driver             215
# Other                    143
# Moped Driver              21
# Motorcycle Passenger      14
# Driver - Not Hit          11
# Wheelchair                10
# In-Line Skater             4
# Trailer Owner              2
# Pedestrian - Not Hit       1
# Witness                    1
# Name: INVTYPE, dtype: int64

# %%
# if values in INVTYPE is not of Fatal ACCCLASS then we can remove those records

# %%
df[(df["INVTYPE"].isna()) & (df["ACCLASS"] == "Fatal")]
# Out:
#                 STREET1         STREET2      ROAD_CLASS        DISTRICT  \
# 9560    98 HAVENDALE RD              NA       Collector     Scarborough
# 10446  CHILTERN HILL RD  EGLINTON AVE W  Major Arterial      North York
# 14021         LESLIE ST  EGLINTON AVE E  Major Arterial      North York
# 14096   TWENTY SIXTH ST   LABURNHAM AVE           Local  Etobicoke York
# 14662     23 IANHALL RD              NA           Local      North York
#
#        WARDNUM   LATITUDE  LONGITUDE      LOCCOORD    TRAFFCTL VISIBILITY  \
# 9560        22  43.792746 -79.284488     Mid-Block  No Control      Clear
# 10446      812  43.700518 -79.427753  Intersection   Stop Sign      Clear
# 14021     1516  43.718589 -79.350383  Intersection   Stop Sign      Clear
# 14096        3  43.599353 -79.525653     Mid-Block  No Control      Clear
# 14662        6  43.727904 -79.488223     Mid-Block  No Control       Snow
#
#           LIGHT    RDSFCOND ACCLASS              IMPACTYPE INVTYPE   INVAGE  \
# 9560       Dark         Dry   Fatal              SMV Other     NaN  unknown
# 10446  Daylight         Dry   Fatal  Pedestrian Collisions     NaN  unknown
# 14021  Daylight         Dry   Fatal       Turning Movement     NaN  unknown
# 14096  Daylight         Dry   Fatal  Pedestrian Collisions     NaN  unknown
# 14662  Daylight  Loose Snow   Fatal  Pedestrian Collisions     NaN  unknown
#
#       INJURY  FATAL_NO INITDIR                       VEHTYPE    MANOEUVER  \
# 9560     NaN       NaN     NaN                           NaN          NaN
# 10446    NaN       NaN     NaN                           NaN          NaN
# 14021   None       NaN     NaN                           NaN          NaN
# 14096    NaN       NaN     NaN  Truck - Closed (Blazer, etc)          NaN
# 14662   None       NaN    East     Automobile, Station Wagon  Going Ahead
#
#       DRIVACT DRIVCOND PEDTYPE PEDACT PEDCOND CYCLISTYPE CYCACT CYCCOND  \
# 9560      NaN      NaN     NaN    NaN     NaN        NaN    NaN     NaN
# 10446     NaN      NaN     NaN    NaN     NaN        NaN    NaN     NaN
# 14021     NaN      NaN     NaN    NaN     NaN        NaN    NaN     NaN
# 14096     NaN      NaN     NaN    NaN     NaN        NaN    NaN     NaN
# 14662     NaN      NaN     NaN    NaN     NaN        NaN    NaN     NaN
#
#       PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 9560         NaN     NaN        Yes        Yes   NaN           NaN       NaN
# 10446        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 14021        NaN     NaN        Yes        NaN   Yes           NaN       NaN
# 14096        Yes     NaN        NaN        NaN   Yes           NaN       NaN
# 14662        Yes     NaN        Yes        NaN   NaN           NaN       NaN
#
#       PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158  \
# 9560        NaN      Yes     Yes      NaN     NaN        NaN      128
# 10446       NaN      NaN     Yes      NaN     NaN        NaN      106
# 14021       NaN      NaN     NaN      NaN     NaN        NaN       42
# 14096       NaN      NaN     NaN      NaN     NaN        NaN       19
# 14662       NaN      NaN     NaN      NaN     NaN        NaN      155
#
#                   NEIGHBOURHOOD_158 HOOD_140  \
# 9560   Agincourt South-Malvern West      128
# 10446            Humewood-Cedarvale      106
# 14021             Banbury-Don Mills       42
# 14096                   Long Branch       19
# 14662                     Downsview       26
#
#                         NEIGHBOURHOOD_140 DIVISION  ObjectId  ACC_NUM  \
# 9560   Agincourt South-Malvern West (128)      D42      9561   3121.0
# 10446            Humewood-Cedarvale (106)      D13     10447   3292.0
# 14021              Banbury-Don Mills (42)      D33     14022   3891.0
# 14096                    Long Branch (19)      D22     14097   3892.0
# 14662           Downsview-Roding-CFB (26)      D31     14663   3858.0
#
#       TIME_SEGMENT
# 9560         Night
# 10446      Morning
# 14021    Afternoon
# 14096    Afternoon
# 14662    Afternoon

# %%
 # It has values where with Fatal ACCLASS

# %%
df['INVTYPE'].fillna('Driver', inplace=True)

# %%
df.INVTYPE.isna().sum()
# Out:
# 0

# %% [markdown]
# # #INVAGE

# %%
# Chcking value of INVAGE

# %%
df.INVAGE.value_counts()
# Out:
# unknown     2339
# 20 to 24     994
# 25 to 29     984
# 40 to 44     852
# 35 to 39     811
# 50 to 54     801
# 45 to 49     797
# 30 to 34     790
# 55 to 59     630
# 15 to 19     507
# 60 to 64     480
# 65 to 69     371
# 70 to 74     318
# 75 to 79     268
# 80 to 84     209
# 85 to 89     146
# 10 to 14     134
# 5 to 9       117
# 0 to 4        90
# 90 to 94      43
# Over 95        9
# Name: INVAGE, dtype: int64

# %%
# Age columns is important and has large number of unknown values

# %%
# we will do one label encoding for age columns and then drop sep

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder and transform 'INVAGE' column
df['INVAGE'] = label_encoder.fit_transform(df['INVAGE'])

df
# Out:
#                  STREET1              STREET2      ROAD_CLASS  \
# 0             BLOOR ST W          DUNDAS ST W  Major Arterial
# 1             BLOOR ST W          DUNDAS ST W  Major Arterial
# 2        MORNINGSIDE AVE       SHEPPARD AVE E  Major Arterial
# 3           WOODBINE AVE          O CONNOR DR  Major Arterial
# 4        MORNINGSIDE AVE       SHEPPARD AVE E  Major Arterial
# ...                  ...                  ...             ...
# 14960  LAKE SHORE BLVD W  BRITISH COLUMBIA RD  Major Arterial
# 14964  LAKE SHORE BLVD W  BRITISH COLUMBIA RD  Major Arterial
# 14967  LAKE SHORE BLVD W  BRITISH COLUMBIA RD  Major Arterial
# 14980     ST CLAIR AVE E          JEANETTE ST  Minor Arterial
# 14981     ST CLAIR AVE E          JEANETTE ST  Minor Arterial
#
#                     DISTRICT  WARDNUM   LATITUDE  LONGITUDE      LOCCOORD  \
# 0      Toronto and East York        4  43.656345 -79.452490  Intersection
# 1      Toronto and East York        4  43.656345 -79.452490  Intersection
# 2                Scarborough       25  43.801943 -79.199786  Intersection
# 3      Toronto and East York       19  43.699595 -79.318797  Intersection
# 4                Scarborough       25  43.801943 -79.199786  Intersection
# ...                      ...      ...        ...        ...           ...
# 14960             North York       10  43.630515 -79.427158     Mid-Block
# 14964             North York       10  43.630515 -79.427158     Mid-Block
# 14967             North York       10  43.630515 -79.427158     Mid-Block
# 14980            Scarborough       20  43.719565 -79.247051  Intersection
# 14981            Scarborough       20  43.719565 -79.247051  Intersection
#
#              TRAFFCTL VISIBILITY     LIGHT RDSFCOND           ACCLASS  \
# 0      Traffic Signal      Clear  Daylight      Dry             Fatal
# 1      Traffic Signal      Clear  Daylight      Dry             Fatal
# 2      Traffic Signal      Clear  Daylight      Dry             Fatal
# 3          No Control      Clear      Dark      Wet  Non-Fatal Injury
# 4      Traffic Signal      Clear  Daylight      Dry             Fatal
# ...               ...        ...       ...      ...               ...
# 14960      No Control      Clear  Daylight      Dry             Fatal
# 14964      No Control      Clear  Daylight      Dry             Fatal
# 14967      No Control      Clear  Daylight      Dry             Fatal
# 14980  Traffic Signal      Clear  Daylight      Dry             Fatal
# 14981  Traffic Signal      Clear  Daylight      Dry             Fatal
#
#                    IMPACTYPE            INVTYPE  INVAGE INJURY  FATAL_NO  \
# 0      Pedestrian Collisions             Driver      20   None       NaN
# 1      Pedestrian Collisions         Pedestrian      13  Fatal       NaN
# 2           Turning Movement  Motorcycle Driver       8  Fatal       NaN
# 3                Approaching          Passenger      10  Major       NaN
# 4           Turning Movement             Driver      20   None       NaN
# ...                      ...                ...     ...    ...       ...
# 14960            Approaching             Driver       5    NaN       NaN
# 14964            Approaching             Driver       5    NaN       NaN
# 14967            Approaching             Driver      11   None       NaN
# 14980  Pedestrian Collisions         Pedestrian      12  Fatal      49.0
# 14981  Pedestrian Collisions             Driver      20   None       NaN
#
#       INITDIR                    VEHTYPE      MANOEUVER  \
# 0       South  Automobile, Station Wagon   Turning Left
# 1       North                      Other            NaN
# 2        East                 Motorcycle  Turning Right
# 3         NaN                        NaN            NaN
# 4       South  Automobile, Station Wagon    Going Ahead
# ...       ...                        ...            ...
# 14960    East  Automobile, Station Wagon    Going Ahead
# 14964    East  Automobile, Station Wagon    Going Ahead
# 14967    West  Automobile, Station Wagon    Going Ahead
# 14980   North                        NaN            NaN
# 14981    East              Passenger Van    Going Ahead
#
#                             DRIVACT     DRIVCOND  \
# 0      Failed to Yield Right of Way      Unknown
# 1                               NaN          NaN
# 2         Disobeyed Traffic Control      Unknown
# 3                               NaN          NaN
# 4                  Driving Properly      Unknown
# ...                             ...          ...
# 14960              Driving Properly       Normal
# 14964              Driving Properly       Normal
# 14967                  Lost control  Inattentive
# 14980                           NaN          NaN
# 14981     Disobeyed Traffic Control      Unknown
#
#                                                  PEDTYPE  \
# 0                                                    NaN
# 1      Vehicle turns left while ped crosses with ROW ...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14960                                                NaN
# 14964                                                NaN
# 14967                                                NaN
# 14980  Vehicle is going straight thru inter.while ped...
# 14981                                                NaN
#
#                            PEDACT  PEDCOND CYCLISTYPE CYCACT CYCCOND  \
# 0                             NaN      NaN        NaN    NaN     NaN
# 1      Crossing with right of way  Unknown        NaN    NaN     NaN
# 2                             NaN      NaN        NaN    NaN     NaN
# 3                             NaN      NaN        NaN    NaN     NaN
# 4                             NaN      NaN        NaN    NaN     NaN
# ...                           ...      ...        ...    ...     ...
# 14960                         NaN      NaN        NaN    NaN     NaN
# 14964                         NaN      NaN        NaN    NaN     NaN
# 14967                         NaN      NaN        NaN    NaN     NaN
# 14980  Crossing with right of way  Unknown        NaN    NaN     NaN
# 14981                         NaN      NaN        NaN    NaN     NaN
#
#       PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 0            Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 1            Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 2            NaN     NaN        Yes        Yes   NaN           NaN       NaN
# 3            NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 4            NaN     NaN        Yes        Yes   NaN           NaN       NaN
# ...          ...     ...        ...        ...   ...           ...       ...
# 14960        NaN     NaN        Yes        Yes   NaN           NaN       NaN
# 14964        NaN     NaN        Yes        Yes   NaN           NaN       NaN
# 14967        NaN     NaN        Yes        Yes   NaN           NaN       NaN
# 14980        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 14981        Yes     NaN        Yes        NaN   NaN           NaN       NaN
#
#       PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158  \
# 0           NaN      NaN     Yes      NaN     NaN        NaN       88
# 1           NaN      NaN     Yes      NaN     NaN        NaN       88
# 2           NaN      NaN     Yes      Yes     NaN        NaN      146
# 3           Yes      Yes     Yes      NaN     Yes        NaN       60
# 4           NaN      NaN     Yes      Yes     NaN        NaN      146
# ...         ...      ...     ...      ...     ...        ...      ...
# 14960       NaN      NaN     NaN      NaN     NaN        NaN      163
# 14964       NaN      NaN     NaN      NaN     NaN        NaN      163
# 14967       NaN      NaN     NaN      NaN     NaN        NaN      163
# 14980       NaN      NaN     Yes      Yes     NaN        NaN      123
# 14981       NaN      NaN     Yes      Yes     NaN        NaN      123
#
#                NEIGHBOURHOOD_158 HOOD_140      NEIGHBOURHOOD_140 DIVISION  \
# 0                High Park North       88   High Park North (88)      D11
# 1                High Park North       88   High Park North (88)      D11
# 2                   Malvern East      132          Malvern (132)      D42
# 3               Woodbine-Lumsden       60  Woodbine-Lumsden (60)      D55
# 4                   Malvern East      132          Malvern (132)      D42
# ...                          ...      ...                    ...      ...
# 14960  Fort York-Liberty Village       82           Niagara (82)      D14
# 14964  Fort York-Liberty Village       82           Niagara (82)      D14
# 14967  Fort York-Liberty Village       82           Niagara (82)      D14
# 14980                 Cliffcrest      123       Cliffcrest (123)      D41
# 14981                 Cliffcrest      123       Cliffcrest (123)      D41
#
#        ObjectId  ACC_NUM TIME_SEGMENT
# 0             1     60.0      Morning
# 1             2     60.0      Morning
# 2             3     61.0      Morning
# 3             4      0.0     Midnight
# 4             5     61.0      Morning
# ...         ...      ...          ...
# 14960     14961   3880.0      Evening
# 14964     14965   3880.0      Evening
# 14967     14968   3880.0      Evening
# 14980     14981   3898.0      Morning
# 14981     14982   3898.0      Morning
#
# [11690 rows x 50 columns]

# %%
#

# %% [markdown]
# # Code above this SECTION

# %%
# First result: Total null values for each feature
null_counts = df.isnull().sum()
null_df = pd.DataFrame(null_counts, columns=["Missing Values"])

# Second result: Total unique values for each feature
unique_values = df.nunique().reset_index()
unique_values.columns = ["Feature", "Unique Values"]

# Combine the two DataFrames
combined_df = pd.merge(unique_values, null_df, left_on="Feature", right_index=True)

# Display the combined DataFrame
print(combined_df)
# Out:
#               Feature  Unique Values  Missing Values
# 0             STREET1           1202               0
# 1             STREET2           1954               0
# 2          ROAD_CLASS              8               0
# 3            DISTRICT              4               0
# 4             WARDNUM             66               0
# 5            LATITUDE           2361               0
# 6           LONGITUDE           2759               0
# 7            LOCCOORD              7               0
# 8            TRAFFCTL             10               0
# 9          VISIBILITY              8               0
# 10              LIGHT              9               0
# 11           RDSFCOND              8               0
# 12            ACCLASS              2               0
# 13          IMPACTYPE             10               0
# 14            INVTYPE             17               0
# 15             INVAGE             21               0
# 16             INJURY              5            1600
# 17           FATAL_NO             78           11097
# 18            INITDIR              5            3717
# 19            VEHTYPE             24             838
# 20          MANOEUVER             16            5294
# 21            DRIVACT             13            6076
# 22           DRIVCOND             10            6080
# 23            PEDTYPE             16            9749
# 24             PEDACT             15            9756
# 25            PEDCOND             10            9763
# 26         CYCLISTYPE             22           11236
# 27             CYCACT             11           11250
# 28            CYCCOND             10           11251
# 29         PEDESTRIAN              1            6924
# 30            CYCLIST              1           10504
# 31         AUTOMOBILE              1            1016
# 32         MOTORCYCLE              1           10911
# 33              TRUCK              1           10903
# 34      TRSN_CITY_VEH              1           10934
# 35          EMERG_VEH              1           11679
# 36          PASSENGER              1            7569
# 37           SPEEDING              1           10179
# 38            AG_DRIV              1            5700
# 39           REDLIGHT              1           10649
# 40            ALCOHOL              1           11121
# 41         DISABILITY              1           11364
# 42           HOOD_158            159               0
# 43  NEIGHBOURHOOD_158            159               0
# 44           HOOD_140            141               0
# 45  NEIGHBOURHOOD_140            141               0
# 46           DIVISION             17               0
# 47           ObjectId          11690               0
# 48            ACC_NUM           3911               0
# 49       TIME_SEGMENT              5               0
